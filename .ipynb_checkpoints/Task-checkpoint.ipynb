# %%
import numpy as np
import pandas as pd
import re

import nltk

# %%
# Dataset directory, set this before your experiments
dataset = '/home/syed.b/emails.csv'

# %%
# Pick a sample for understanding perspective
df_sample  = pd.read_csv(dataset, skiprows = lambda x : np.random.rand() > 0.01 and x > 0)

# %%
df_sample.shape
# Out:
# (5148, 2)

# %%
df_sample['message'][0]
# Out:
# "Message-ID: <2068674.1075855691152.JavaMail.evans@thyme>\nDate: Tue, 25 Apr 2000 05:22:00 -0700 (PDT)\nFrom: phillip.allen@enron.com\nTo: hargr@webtv.net\nSubject: Re: #30\nMime-Version: 1.0\nContent-Type: text/plain; charset=us-ascii\nContent-Transfer-Encoding: 7bit\nX-From: Phillip K Allen\nX-To: hargr@webtv.net (Neal Hargrove) @ ENRON\nX-cc: \nX-bcc: \nX-Folder: \\Phillip_Allen_Dec2000\\Notes Folders\\'sent mail\nX-Origin: Allen-P\nX-FileName: pallen.nsf\n\n2000-1969=31"

# %%
# Establish cleaning patterns

[ x.strip() for x in df_sample['message'][11].split('FileName:')[1].split('\n',1)[1].strip('\n').split('\n') if x]
# Out:
# ['---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/30/2000',
#  '09:14 AM ---------------------------',
#  '',
#  '',
#  'Enron Technology',
#  '',
#  'From:  Stephen Stock                           10/27/2000 12:49 PM',
#  '',
#  'To: Phillip K Allen/HOU/ECT@ECT',
#  'cc:',
#  'Subject: ERMS / RMS Databases',
#  'Phillip,',
#  'It looks as though we have most of the interim hardware upgrades in the',
#  'building now, although we are still expecting a couple of components to',
#  'arrive on Monday.',
#  'The Unix Team / DBA Team and Applications team expect to have a working test',
#  "server environment on Tuesday. If anything changes, I'll let you know.",
#  'best regards',
#  'Steve Stock']

# %%
# Load the whole data

df = pd.read_csv(dataset)

# %%
df.shape
# Out:
# (517401, 2)

# %%
# Store emails here in the list
# Use nltk's sentence tokenizer to tokenize the email sentences -- since we notice above that 
# order
emails = []

for i in range(df.shape[0]):
    
    emails.append(nltk.sent_tokenize(' '.join([ x.strip() for x in df['message'][i].split('FileName:')[1].split('\n',1)[1].strip('\n').split('\n') if x]
)))

# %%
#Sanity check
emails[1]
# Out:
# ['Traveling to have a business meeting takes the fun out of the trip.',
#  'Especially if you have to prepare a presentation.',
#  'I would suggest holding the business plan meetings here then take a trip without any formal business meetings.',
#  'I would even try and get some honest opinions on whether a trip is even desired or necessary.',
#  'As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#  'Too often the presenter speaks and the others are quiet just waiting for their turn.',
#  'The meetings might be better if held in a round table discussion format.',
#  'My suggestion for where to go is Austin.',
#  "Play golf and rent a ski boat and jet ski's.",
#  'Flying somewhere takes too much time.']

# %%
# Read in action verbs
action_verbs = []
with open('./action_verbs.txt', 'r') as f:
    for line in f:
        action_verbs.append(line.strip().lower())
# Storing the actionable items as a tuple - (text, action-verb)
action_texts = []   
for item in emails[:10000]:
    for text in item:
        for verb in action_verbs:
            if verb in text.lower().split():
                action_texts.append((text, verb))
                break

# %%
action_texts
# Out:
# [('As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#   'think'),
#  ('My suggestion for where to go is Austin.', 'go'),
#  ("Play golf and rent a ski boat and jet ski's.", 'play'),
#  ('Randy, Can you send me a schedule of the salary and level of everyone in the scheduling group.',
#   'send'),
#  ('Please cc the following distribution list with updates: Phillip Allen (pallen@enron.com) Mike Grigsby (mike.grigsby@enron.com) Keith Holst (kholst@enron.com) Monique Sanchez Frank Ermis John Lavorato Thank you for your help Phillip Allen',
#   'help'),
#  ("1. login:  pallen pw: ke9davis I don't think these are required by the ISP 2.  static IP address IP: 64.216.90.105 Sub: 255.255.255.248 gate: 64.216.90.110 DNS: 151.164.1.8 3.",
#   'think'),
#  ('kWh deal must have limited/ > no risk forward gas price to make deal work.',
#   'make'),
#  ('> > For 6-8 hours a day  Microturbine run time: > Gas requirement for 180 microturbines 227 - 302 MMcf per year > Gas requirement for 240 microturbines 302 - 403 MMcf per year > > Gas will likely be consumed from May through September, during peak > electric period.',
#   'run'),
#  ('Lucy, Here are the rentrolls: Open them and save in the rentroll folder.',
#   'open'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/09/2000 02:16 PM --------------------------- Richard Burchfield 10/06/2000 06:59 AM To: Phillip K Allen/HOU/ECT@ECT cc: Beth Perlman/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list Phillip, Below is the issues & to do list as we go forward with documenting the requirements for consolidated physical/financial positions and transport trade capture.',
#   'go'),
#  ('Throughout the meeting on Wednesday, Keith alluded to the inability to get consensus amongst the traders on the presentation of the consolidated position, so the solution was to make it so that a trader can arrange the position screen to their liking (much like Excel).',
#   'make'),
#  ("Richard ---------------------- Forwarded by Richard Burchfield/HOU/ECT on 10/06/2000 08:34 AM --------------------------- Allan Severude 10/05/2000 06:03 PM To: Richard Burchfield/HOU/ECT@ECT cc: Peggy Alix/HOU/ECT@ECT, Russ Severson/HOU/ECT@ECT, Scott Mills/HOU/ECT@ECT, Kenny Ha/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list From our initial set of meetings with the traders regarding consolidated positions, I think we still have the following issues: We don't have a single point of contact from the trading group.",
#   'think'),
#  ('We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#   'come'),
#  ("We're getting hit with a lot of different requests, many of which appear to be outside the scope of position consolidation.",
#   'hit'),
#  ("Things left to do: I think it may be useful to try to formulate a high level project goal to make it as clear as possible what we're trying to accomplish with this project.",
#   'make'),
#  ("It'll help determine which requests fall under the project scope.", 'fall'),
#  ('Go through the list of requests to determine which are in scope for this project and which fall out of scope.',
#   'fall'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/09/2000 02:00 PM --------------------------- Richard Burchfield 10/06/2000 06:59 AM To: Phillip K Allen/HOU/ECT@ECT cc: Beth Perlman/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list Phillip, Below is the issues & to do list as we go forward with documenting the requirements for consolidated physical/financial positions and transport trade capture.',
#   'go'),
#  ('Throughout the meeting on Wednesday, Keith alluded to the inability to get consensus amongst the traders on the presentation of the consolidated position, so the solution was to make it so that a trader can arrange the position screen to their liking (much like Excel).',
#   'make'),
#  ("Richard ---------------------- Forwarded by Richard Burchfield/HOU/ECT on 10/06/2000 08:34 AM --------------------------- Allan Severude 10/05/2000 06:03 PM To: Richard Burchfield/HOU/ECT@ECT cc: Peggy Alix/HOU/ECT@ECT, Russ Severson/HOU/ECT@ECT, Scott Mills/HOU/ECT@ECT, Kenny Ha/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list From our initial set of meetings with the traders regarding consolidated positions, I think we still have the following issues: We don't have a single point of contact from the trading group.",
#   'think'),
#  ('We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#   'come'),
#  ("We're getting hit with a lot of different requests, many of which appear to be outside the scope of position consolidation.",
#   'hit'),
#  ("Things left to do: I think it may be useful to try to formulate a high level project goal to make it as clear as possible what we're trying to accomplish with this project.",
#   'make'),
#  ("It'll help determine which requests fall under the project scope.", 'fall'),
#  ('Go through the list of requests to determine which are in scope for this project and which fall out of scope.',
#   'fall'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/04/2000 04:23 PM ---------------------------  Enron North America Corp.  From:  Airam Arteaga                           10/04/2000 12:23 PM  To: Phillip K Allen/HOU/ECT@ECT, Thomas A Martin/HOU/ECT@ECT, Scott Neal/HOU/ECT@ECT, John Arnold/HOU/ECT@ECT, Grant Masson/HOU/ECT@ECT, Ted Murphy/HOU/ECT@ECT, Vladimir Gorny/HOU/ECT@ECT, Frank Hayden/Corp/Enron@Enron cc: Rita Hennessy/NA/Enron@Enron, Ina Rangel/HOU/ECT@ECT, Laura Harder/Corp/Enron@Enron, Kimberly Brown/HOU/ECT@ECT, Araceli Romero/NA/Enron@Enron, Kimberly Hillis/HOU/ECT@ect Subject: Var, Reporting and Resources Meeting Please plan to attend the below  Meeting: Topic:  Var, Reporting and Resources Meeting  Date:  Wednesday, October 11th Time:  2:30 - 3:30 Location: EB30C1  If you have any questions/conflicts, please feel free to call me.',
#   'call'),
#  ('Can you please make sure he has an active password.', 'make'),
#  ('I think Fletch has a good CPA.', 'think'),
#  ("It doesn't make sense to have monthly indices that are dramatically different.",
#   'make'),
#  ("It doesn't make sense to have monthly indeces that are dramatically different.",
#   'make'),
#  ('As an alternative, we can close into a land loan at probably 70% of appraised value.',
#   'close'),
#  ('This was not presented in the initial analysis as the phasing is depended on a more careful assessment by the Civil Engineer as the separate phases must each be able to stand on its own from a utility standpoint.',
#   'stand'),
#  ('As you, and I presume Keith, want to be involved to learn as much as possible we would make every effort to be accommodating.',
#   'make'),
#  ('Call when you have reviewed and we can discuss further.', 'call'),
#  ('As an alternative, we can close into a land loan at probably 70% of appraised value.',
#   'close'),
#  ('This was not presented in the initial analysis as the phasing is depended on a more careful assessment by the Civil Engineer as the separate phases must each be able to stand on its own from a utility standpoint.',
#   'stand'),
#  ('As you, and I presume Keith, want to be involved to learn as much as possible we would make every effort to be accommodating.',
#   'make'),
#  ('Call when you have reviewed and we can discuss further.', 'call'),
#  ('Once the construction drawings are complete I will send them to you for a revised bid.',
#   'send'),
#  ("I will just need to go back to my closing documents  and see what's there and find out where I am with that and deal with this as  best I can.",
#   'go'),
#  ("I will go back to mine and Phillip Allen's  transaction?and take a look at that but as vague and general as this is I  doubt that my signature?",
#   'go'),
#  ("I really do not want to hold up anything or  generate more work for myself and I don't want to insult or annoy anyone but  this paper really doesn't seem to be something required for a closing.?",
#   'insult'),
#  ('Call me when you can.', 'call'),
#  ('Email me your phone # and I will call you.', 'call'),
#  ('Jim, Is there going to be a conference call or some type of weekly meeting about all the regulatory issues facing California this week?',
#   'call'),
#  ('Can you make sure the gas desk is included.', 'make'),
#  ('Is the plan to wait until the last unit is sold and closed before profits are distributed?',
#   'wait'),
#  ('This will enable us to probably obtain an approved site plan before closing on the contract, which will mean that we can close into an A&D Loan rather than into a land loan and then an improvement loan.',
#   'close'),
#  ('I will send you a package on the property that was prepared by the broker, by Airborne Express today for Saturday delivery.',
#   'send'),
#  ('Once you have read the package and reviewed this proforma, we would want to schedule a tour of the site and the area.',
#   'read'),
#  ('Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#   'call'),
#  ('A small freakish wind storm with severe 60+mpg downdrafts hit the South part of Austin where we are building 10 town homes.',
#   'hit'),
#  ('I will follow up with an email and phone call about Cherry Creek.', 'call'),
#  ('You can fill in on the computer or just write in the correct amounts and I will input.',
#   'write'),
#  ('I will go ahead and mail you another check.', 'go'),
#  ('I will find that amortization schedule and send it soon.', 'send'),
#  ('This will enable us to probably obtain an approved site plan before closing on the contract, which will mean that we can close into an A&D Loan rather than into a land loan and then an improvement loan.',
#   'close'),
#  ('I will send you a package on the property that was prepared by the broker, by Airborne Express today for Saturday delivery.',
#   'send'),
#  ('Once you have read the package and reviewed this proforma, we would want to schedule a tour of the site and the area.',
#   'read'),
#  ('Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#   'call'),
#  ('A small freakish wind storm with severe 60+mpg downdrafts hit the South part of Austin where we are building 10 town homes.',
#   'hit'),
#  ('In fact, if we were able to purchase additional lots from Regan we would build 4 bedroom units along with the 3-bedroom plan.',
#   'build'),
#  ('Phillip, I will call you today to go over this more thoroughly.', 'call'),
#  ('This will enable us to probably obtain an approved site plan before closing on the contract, which will mean that we can close into an A&D Loan rather than into a land loan and then an improvement loan.',
#   'close'),
#  ('I will send you a package on the property that was prepared by the broker, by Airborne Express today for Saturday delivery.',
#   'send'),
#  ('Once you have read the package and reviewed this proforma, we would want to schedule a tour of the site and the area.',
#   'read'),
#  ('Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#   'call'),
#  ('A small freakish wind storm with severe 60+mpg downdrafts hit the South part of Austin where we are building 10 town homes.',
#   'hit'),
#  ('It is important that you complete this assessment NO LATER THAN CLOSE OF BUSINESS Thursday, September 14.',
#   'close'),
#  ('To complete your assessment, please click on the following link or simply open your internet browser and go to: http://www.fsddatasvc.com/enron Your unique ID for each participant you have been asked to rate is: Unique ID - Participant EVH3JY - John Arnold ER93FX - John Lavorato EPEXWX - Hunter Shively If you experience technical problems, please call Dennis Ward at FSD Data Services, 713-942-8436.',
#   'call'),
#  ('Larry, Just a note to touch base on the sagewood townhomes and other development opportunities.',
#   'touch'),
#  ('Call or email with your thoughts.', 'call'),
#  ('After migration of your mailbox, you will not be able to send or recieve ma= il via Notes, and you will not be able to start using Outlook until it is c= onfigured by the Outlook Migration team the morning after your mailbox is m= igrated.',
#   'send'),
#  ('During this period, you can use Outlook Web Access (OWA) via your= web browser (Internet Explorer 5.0) to read and send mail.',
#   'read'),
#  ('There are future plans to make OWA availab= le from your home or when traveling abroad.',
#   'make'),
#  ('Data centers, also known as co-location facilities and server farms, are sprouting at such a furious pace in Tukwila and the Kent Valley that some have expressed concern over whether Seattle City Light and Puget Sound Energy can handle the power necessary to run these 24-hour, high-security facilities.',
#   'run'),
#  ('Not to be left behind, Seattle City Light plans to bring up the data center issue on Thursday at the Seattle City Council meeting.',
#   'bring'),
#  ('The facilities run 24 hours a day, seven days a week, and therefore could become a constant revenue stream.',
#   'run'),
#  ('Who will pay for those expenditures and what it will mean for power rates in the area is still open to debate.',
#   'open'),
#  ('"These facilities are what we call extremely dense loads," said Bob Royer, director of communications and public affairs at Seattle City Light.',
#   'call'),
#  ('While companies such as Amazon.com run their own server farms, many high-tech companies have decided to outsource the operations to companies such as Exodus that may be better prepared for dealing with Internet traffic management.',
#   'run'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 09/06/2000 10:44 AM --------------------------- John J Lavorato@ENRON 09/06/2000 05:39 AM To: Phillip K Allen/HOU/ECT@ECT cc: Subject: Re: The commercial support people that you and Hunter want to make commercial managers.',
#   'make'),
#  ('Without the email address, we cannot email them their internet link and ID to provide feedback for you, nor can we send them an automatic reminder via email.',
#   'send'),
#  ('Without the email address, we cannot email them their internet link and ID to provide feedback for you, nor can we send them an automatic reminder via email.',
#   'send'),
#  ("When you finish, simply click on the 'Reply' button then hit 'Se= nd'  Your survey will automatically be sent to the Outlook 2000 Migration M= ailbox.",
#   'hit'),
#  ('Brenda Can you send me your address in College Station.', 'send'),
#  ('I have set up a composite page with western basis and cash prices to help you filter through the products.',
#   'help'),
#  ('If you have any problems logging in you can call me at (713)853-7041 or Kathy Moore, EnronOnline HelpDesk, 713/853-HELP (4357).',
#   'call'),
#  ('After opening "About EnronOnline", using right scroll bar, go to the bottom.',
#   'go'),
#  ('Please call with any questions.', 'call'),
#  ('Call me if you did not receive them.', 'call'),
#  ('Use a formula in column E.  Add the value in column C to column D.  It should read =c6+d6.',
#   'read'),
#  ('After we get the rent part fixed, lets bring the database columns up to this sheet and place them to the right in columns J and beyond.',
#   'bring'),
#  ('You will probably need to close the file before you attach to an email.',
#   'close'),
#  ('I really want to make some progress on these two files.', 'make'),
#  ('Lucy, Please open this excel file and input the rents and names due for this week.',
#   'open'),
#  ('Open the "utility" spreadsheet and try to complete the analysis of whether it is better to be a small commercial or a medium commercial (LP-1).',
#   'open'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ('I think crude price are undervalued by the tune of $10/share.', 'think'),
#  ("Gas 34 Crude  10 Total  81  Can you take a look at these numbers and play devil's advocate?",
#   'play'),
#  ('To me this looks like the best stock to own Also can you send me a report on Calpine, Tosco, and SLB?',
#   'send'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 08/20/2000 05:39 PM --------------------------- "Lucy Gonzalez" <stagecoachmama@hotmail.com> on 08/15/2000 02:32:57 PM To: pallen@enron.com cc: Subject: Daily Duties Phillip, We have been working on different apartments today and having to listen to different, people about what Mary is saying should i be worried?',
#   'listen'),
#  ("ants seem to be invading my apartment.You got my other fax's Wade is working on the bulletin board that I need up so that I can let tenants know about what is going on.Gave #25 a notice about having to many people staying in that apt and that problem has been resolved.Also I have a tenant in #29 that is complaining about #28 using fowl language.I sent #28 a lease violation we will see how that goes call you tomorrow Thanx Lucy ________________________________________________________________________ Get Your Private, Free E-mail from MSN Hotmail at http://www.hotmail.com",
#   'call'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 08/20/2000 05:38 PM --------------------------- "Lucy Gonzalez" <stagecoachmama@hotmail.com> on 08/17/2000 02:37:55 PM To: pallen@enron.com cc: Subject: Daily Report Phillip, Today was one of those days because Wade had to go pay his fine and I had to go take him that takes alot of time out of my schedule.If you get a chance will you mention to him that he needs to, try to fix his van so tht he can go get what ever he needs.',
#   'go'),
#  ('Tomorrow gary is going to be here.I have to go but Iwill E-Mail you tomorrow Lucy ________________________________________________________________________ Get Your Private, Free E-mail from MSN Hotmail at http://www.hotmail.com',
#   'go'),
#  ('I am starting to exercise now, but I am going to use the proceeds to buy another apartment complex.',
#   'buy'),
#  ('What do you think about selling JDSU and buying SDLI?', 'think'),
#  ('Also can you look at EOG as a play on rising oil and gas prices.', 'play'),
#  ('also, what do I need to enter under domain?', 'enter'),
#  ('Date:  Friday August 18, 2000 Time:  2:30 pm - 4:30 pm Location: 30C1  Topic:   ENA Management Committee  If you have any questions or conflicts, please feel free to call me (3-0643) or Bev (3-7857).',
#   'call'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ('I tried to run the model and it did not work', 'run'),
#  ("The point of this meeting is to get all issues out in the open and make sure everyone is comfortable with using the model and position manager, and to make sure those who are managing the books believe in the model's results.",
#   'make'),
#  ('When you open the file, go to the "Checkbook" tab and look at the yellow highlighted items.',
#   'go'),
#  ('Ina, How many times do you think Jeff wants to get this message.', 'think'),
#  ('Please help Phillip ---------------------- Forwarded by Phillip K Allen/HOU/ECT on 08/08/2000 04:30 PM ---------------------------    From:  Jeffrey A Shankman                           08/08/2000 05:59 AM  To: Phillip K Allen/HOU/ECT@ECT cc: Paul T Lucci/DEN/ECT@Enron Subject: Your Approval is Overdue: Access Request for paul.t.lucci@enron.com Please have Phillip or John L approve.',
#   'help'),
#  ('Phillip ---------------------- Forwarded by Phillip K Allen/HOU/ECT on 08/08/2000 04:28 PM --------------------------- ARSystem@ect.enron.com on 08/08/2000 07:17:38 AM To: phillip.k.allen@enron.com cc: Subject: Request Submitted: Access Request for frank.ermis@enron.com Please review and act upon this request.',
#   'act'),
#  ("When you finis= h, simply click on the 'Reply With History' button then hit 'Send'  Your su= rvey will automatically be sent to the Outlook 2000 Migration Mailbox.",
#   'hit'),
#  ('Send to Karen Buckley.', 'send'),
#  ('can you build something to look at historical prices from where we saved curves each night.',
#   'build'),
#  ('Lucy, I will call you this afternoon to discuss the things in your email.',
#   'call'),
#  ('Could you give me a basis for the period : Sept -00 - May 31, 2006 Sept-00 - May 31, 2008 Since I assume you do not keep a Stanfield basis, but rather a basis off Malin or Rockies, it would probably make sense to show the basis as an adjustment to one of these point.',
#   'make'),
#  ('If you decide to buy a small truck and you want to list me as an employer for credit purposes, I will vouch for your income.',
#   'buy'),
#  ('Can you email or call with some additional insight?', 'call'),
#  ("Come see what's new www.skippingstone.com Energy Experts Consulting to the Energy Industry !",
#   'come'),
#  ('If you have any questions, please call me on 3-7041 Thanks, Phillip Allen',
#   'call'),
#  ("I will try to bring some pictures if I can't bring the real thing.",
#   'bring'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 07/13/2000 10:24 AM --------------------------- From: Andy Chen on 07/12/2000 02:14 PM To: Michael Etringer/HOU/ECT@ECT cc: Frank W Vickers/HOU/ECT@ECT, Saji John/HOU/ECT@ECT, Phillip K Allen/HOU/ECT@ECT, John Arnold/HOU/ECT@ECT Subject: Project Elvis and Cactus Open Gas Position Mike-- Here are the net open Socal border positions we have for Elvis and Cactus.',
#   'open'),
#  ("Let's try and set up a conference call with Phillip and John to talk about their offers at the back-end of their curves.",
#   'call'),
#  ('I am the ENA Staffing Coordinator and need for you to fill out the attached Needs Assessment form before I can send you any resumes.',
#   'send'),
#  ('Once I receive the Needs Assessment back (and you let me know if you can wait a month,) I will be happy to pull a couple of resumes for your review.',
#   'wait'),
#  ('Please call me at x30681 if you have any questions.', 'call'),
#  ('Call Kim Hillis at x30681 if you have any questions.', 'call'),
#  ('If you have any questions, please feel free to call me at x33198.', 'call'),
#  ('Al, I am not in good enough shape to ride a century right now.', 'ride'),
#  ('Speak to your HR representative if you need help getting signed up.',
#   'help'),
#  ("I will read it this weekend and ask my dad about the a/c's.", 'ask'),
#  ('Have a good weekend and I will talk to you next week.', 'talk'),
#  ('Please read the following memo sent to you a few days ago and if you have any questions regarding this request, please feel free to call Ted Bland @ 3-5275.',
#   'call'),
#  ("With Enron's rapid growth we need to maintain an ability to move employees between operating companies and new ventures.",
#   'move'),
#  ('Just go to hrweb.enron.com and look for the HRGIS link.', 'go'),
#  ('You mentioned that you have resources to run the model.', 'run'),
#  ('This will help us to gain experience with the market vs the model.',
#   'help'),
#  ('Basically, can you help us get any clarification on the language "the average daily cost of gas for all delivery points in California"?',
#   'help'),
#  ('Frogger had a great run as an arcade classic, but it is leaving the shockwave.com pond soon.',
#   'run'),
#  ('You can download Shockmachine for free and save all of your downloadable favorites to play off-line, full-screen, whenever you want.',
#   'play'),
#  ('I think I know the answer to your questions but I want to get the exact details from him.',
#   'think'),
#  ('Then once their sales are large enough they will go to the wholesale market to hedge and lock in a profit.',
#   'go'),
#  ('He can call me at work or home.', 'call'),
#  ('Or if you email me his number I will call him.', 'call'),
#  ('I will call you tomorrow to discuss items from the office.', 'call'),
#  ('Do you need Mary to come in on any more Fridays?', 'come'),
#  ('I think I can guess your answer.', 'think'),
#  ('I think that you probably know this already, but there can be a siginificant difference between "scheduled" and "actual" generation.',
#   'think'),
#  ('Having said all of that, it is probably close enough and better than your alternatives on the generation side.',
#   'close'),
#  ('On the load side I think that I would simply use CAISO actual load.',
#   'think'),
#  ('While they don\'t split out NP15 from SP15, I think that using the actual number is better than the "scheduled" number.',
#   'think'),
#  ('The utilities play lots of game on the load side, usually under-scheduling depending on price.',
#   'play'),
#  ('I think the presentation looks good.', 'think'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 06/06/2000 12:27 PM ---------------------------    From:  Phillip K Allen                           06/06/2000 10:26 AM  To: Robert Badeer/HOU/ECT@ECT cc: Subject: http://ecthou-webcl1.nt.ect.enron.com/gas/  All the gas reports are under west desk Call Brian Hoskins for a password',
#   'call'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 06/06/2000 12:26 PM ---------------------------    From:  Phillip K Allen                           06/06/2000 10:26 AM  To: Robert Badeer/HOU/ECT@ECT cc: Subject: http://ecthou-webcl1.nt.ect.enron.com/gas/  All the gas reports are under west desk Call Brian Hoskins for a password',
#   'call'),
#  ('http://ecthou-webcl1.nt.ect.enron.com/gas/  All the gas reports are under west desk Call Brian Hoskins for a password',
#   'call'),
#  ('Please call or email with comments.', 'call'),
#  ('What do you think about being open until noon on Saturday.', 'open'),
#  ('This might be more convenient for collecting rent and showing open apartments.',
#   'open'),
#  ('Sometimes we even hit the trails in Memorial Park on Saturdays.', 'hit'),
#  ('I would like to dust off my road bike and go for a ride some Saturday.',
#   'go'),
#  ('Maybe we could grab lunch sometime.', 'grab'),
#  ("There may be an operational reason why this occurred that I'm not aware of, and the dollar impact is very small, but I thought I'd bring it to your attention just in case there's something you want to do about it.",
#   'bring'),
#  ('We can talk about a unit for Wade then.', 'talk'),
#  ('I will call the bank again today to resolve authorization on the account.',
#   'call'),
#  ('Lets keep the office open until noon on Memorial day.', 'open'),
#  ('This note is authorization to make the following changes: 1.', 'make'),
#  ("Route EPNG Permian to Todd Richardson's book FT-New Texas Call with questions.",
#   'call'),
#  ('Never say never, but I think it is highly unlikely that the final order will contain a fixed price cap.',
#   'think'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 05/19/2000 10:46 AM ---------------------------    From:  Jeffrey A Shankman                           05/18/2000 06:27 PM  To: Phillip K Allen/HOU/ECT@ECT, Keith Holst/HOU/ECT@ect, Mike Grigsby/HOU/ECT@ECT cc: Subject: Large Deal Alert ---------------------- Forwarded by Jeffrey A Shankman/HOU/ECT on 05/18/2000 08:23 PM --------------------------- Bruce Sukaly@ENRON 05/18/2000 08:20 AM To: John Arnold/HOU/ECT@ECT, Mike Maggi/Corp/Enron@Enron, Jeffrey A Shankman/HOU/ECT@ECT cc: Subject: Large Deal Alert To make a long story short.',
#   'make'),
#  ('Please continue to send them daily.', 'send'),
#  ('Call with questions.', 'call'),
#  ('They were polite regarding asset management and procurement function outsourcing and are willing to listen to a proposal.',
#   'listen'),
#  ('Are there any entities that you think would be interested in an asset management deal that we should approach?',
#   'think'),
#  ('How much pipeline capacity do we buy or sell to them?', 'buy'),
#  ('I think my folks are ready to start building.', 'think'),
#  ('We will probably visit in late June or July.', 'visit'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ('I will call you in a day or so.', 'call'),
#  ('mac, We will be there on the 9th and I will bring the paperwork.', 'bring'),
#  ("I don't have my floor plan with me at work today, but will bring in tomorrow and fax you a copy.",
#   'bring'),
#  ('Mary, Go ahead and work with Gary to get a new fridge for #8.', 'go'),
#  ('I am going to try and come down this Saturday.', 'come'),
#  ('Talk to you later.', 'talk'),
#  ('Mark, Thank you for the offer, but I am not doing the ride this year.',
#   'ride'),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 03/22/2000 01:46 PM ---------------------------    From:  Colleen Sullivan                           03/22/2000 08:42 AM  To: Hunter S Shively/HOU/ECT@ECT, Phillip K Allen/HOU/ECT@ECT, Scott Neal/HOU/ECT@ECT, Thomas A Martin/HOU/ECT@ECT cc: Bhavna Pandya/HOU/ECT@ECT Subject: Meeting-THURSDAY, MARCH 23 - 11:15 AM Please plan on attending a meeting on Thursday, March 23 at 11:15 am in Room 3127.',
#   'march'),
#  ('Call me if you have any questions (403) 974-6756.', 'call'),
#  ('I will call you about wade later today Philip', 'call'),
#  ('Call me if you have any questions (403) 974-6756.', 'call'),
#  ("Let's try and schedule a meeting for this Wednesday to go over the items above.",
#   'go'),
#  ("Let's try and schedule a meeting for this Wednesday to go over the items above.",
#   'go'),
#  ('Go ahead and level the floor in #2.', 'go'),
#  ('If the negotiations stall, it seems like I need to go ahead and cut off the utilities.',
#   'go'),
#  ('Hopefully things will go smoothly.', 'go'),
#  ('You should be able to simply click on this URL below and it should come up for you.',
#   'come'),
#  ('Go ahead and order the ac for #27.', 'go'),
#  ('I think $100 should be enough.', 'think'),
#  ('Read album reviews.', 'read'),
#  ('I will call you Monday or Tuesday to see what is new.', 'call'),
#  ("Jeff, Let's just close on March 1.", 'close'),
#  ('Then we turn to the value of =20 transportation at the following three major pricing points with an assessme= nt=20 of  the primary market (firm), secondary market (basis) and asset market: ?????',
#   'turn'),
#  ('The California/SW region=01,s  workshop =01* a key element of the service = =01* will=20 take place on March 20, 2000,at 8:30 AM, at the Arizona Biltmore Hotel in = =20 Phoenix.',
#   'march'),
#  ('Go ahead and get a carpet shampooer.', 'go'),
#  ('Make sure it comes back clean after each use.', 'make'),
#  ('I will call you later today to discuss.', 'call'),
#  ('If you bring a very good lock you should be able to secure the bike at the designated outside racks.',
#   'bring'),
#  ('1023 Fax  (703)893-4390 Cell (443)255-7699 > -----Original Message----- > From: Phillip_K_Allen@enron.com [mailto:Phillip_K_Allen@enron.com] > Sent: Monday, February 07, 2000 5:54 PM > To: george.rahal@acnpower.com > Subject: Re: W basis quotes > > > > George, > >      Can you please call my credit desk at 713-853-1803.',
#   'call'),
#  ('1023 Fax  (703)893-4390 Cell (443)255-7699 > -----Original Message----- > From: Phillip_K_Allen@enron.com [mailto:Phillip_K_Allen@enron.com] > Sent: Monday, February 07, 2000 5:54 PM > To: george.rahal@acnpower.com > Subject: Re: W basis quotes > > > > George, > >      Can you please call my credit desk at 713-853-1803.',
#   'call'),
#  ('George, Can you please call my credit desk at 713-853-1803.', 'call'),
#  ('Kim, Doublecheck with Julie G. , but I think it ok to pay Jan. demand charges.',
#   'think'),
#  ('I think Steven Wolf is the person to talk to about moving Kim Olinger to a different RC code.',
#   'talk'),
#  ('Do we push actual value, seasonal shape, or unwind costs?', 'push'),
#  ('Go to: http://www.living.com/util/login.jhtml I have selected a few pieces that might work for you.',
#   'go'),
#  ("Check out our January Clearance http://living.com/sales/january_clearance.jhtml and our Valentine's Day Gifts http://living.com/shopping/list/list.jhtml?type=2011&sale=valentines -----Original Message----- From: pallen@enron.com [mailto:pallen@enron.com] Sent: Monday, January 17, 2000 5:20 PM To: designadvice@living.com Subject: Choosing a style I am planning to build a house in the Texas hillcountry.",
#   'build'),
#  ('I am considering the following features:  stained and scored concrete floors, an open living/dining/kitchen concept, lots of windows, a home office, 4 bedrooms all upstairs.',
#   'open'),
#  ('Tara, Please make the following changes: FT-West -change master user from Phillip Allen to Keith Holst IM-West-Change master user from Bob Shiring to Phillip Allen Mock both existing profiles.',
#   'make'),
#  ('Please make these changes on 1/17/00 at noon.', 'make'),
#  ('Call me.', 'call'),
#  ("Sure, we could trap you with a free game of Centipede, then kick up the price after you're hooked.",
#   'kick'),
#  ("Get Arcade Classics from shockwave.com, stick 'em in your Shockmachine and then play them offline anytime you want.",
#   'play'),
#  ("This frog won't turn into a handsome prince(ss), but it's sure to bring back great memories of hopping through the arcade -- and this time, you can save your quarters for laundry.",
#   'bring'),
#  ('Shockmachine has a beautiful feature: you can play without being hooked to the Internet.',
#   'play'),
#  ('Grab the game from shockwave.com, save it to your hard drive, and play offline!',
#   'grab'),
#  ("Here's your chance to do it at home - Shockmachine lets you play your favorite arcade games straight from your computer.",
#   'play'),
#  ("I just don't want Vishal to go unrepresented since he changed groups mid year.",
#   'go'),
#  ('Call me with questions.', 'call'),
#  ("When you finish, simply click on the 'Reply With History' button then hit 'Send'  Your survey will automatically be sent to the Outlook 2000 Migration Mailbox.",
#   'hit'),
#  ('If the negotiations stall, it seems like I need to go ahead and cut off the utilities.',
#   'go'),
#  ('Hopefully things will go smoothly.', 'go'),
#  ('Send his resume to Karen Buckley.', 'send'),
#  ('Can you guys coordinate to make sure someone listens to this conference call each week.',
#   'call'),
#  ('Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Please forward to anyone on your team that wants updates on Western wholesale matters (should also give you an opportunity to raise state matters if you want to discuss).',
#   'call'),
#  ("Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Date:   Every Thursday Time:    1:00 pm Pacific, 3:00 pm Central, and 4:00 pm Eastern time, Number:   1-888-271-0949, Host Code:  661877, (for Jim only), Participant Code: 936022, (for everyone else), Attached is the table of the on-going FERC issues and proceedings updated for use on tomorrow's conference call.",
#   'call'),
#  ('I will be unable to participate in the call tomorrow as I will be attending the Senate Energy and Resource Committee Hearing on the elements of the FERC market monitoring and mitigation order.',
#   'call'),
#  ('Bridge Loan Financing Bills May Not Meet Their May 8th Deadline Due to Lack of Support Sources report there will not be a vote regarding the authorization for the bond issuance/bridge loan by the May 8th deadline.',
#   'vote'),
#  ("Sources report that the Republicans intend to hold out for full disclosure of the governor's plan for handling the crisis, including the details and terms of all long-term contracts he has negotiated, before they will support the bond issuance to go forward.",
#   'go'),
#  ('According to sources close to the Republicans in  the legislature, Republicans do not believe there should be a bridge loan due to money available in the General Fund.',
#   'close'),
#  ('The Republicans intend to bring this up in debate on  Monday.', 'bring'),
#  ('Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Please forward to anyone on your team that wants updates on Western wholesale matters (should also give you an opportunity to raise state matters if you want to discuss).',
#   'call'),
#  ("Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Date:   Every Thursday Time:    1:00 pm Pacific, 3:00 pm Central, and 4:00 pm Eastern time, Number:   1-888-271-0949, Host Code:  661877, (for Jim only), Participant Code: 936022, (for everyone else), Attached is the table of the on-going FERC issues and proceedings updated for use on tomorrow's conference call.",
#   'call'),
#  ('I will be unable to participate in the call tomorrow as I will be attending the Senate Energy and Resource Committee Hearing on the elements of the FERC market monitoring and mitigation order.',
#   'call'),
#  ('As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#   'think'),
#  ('My suggestion for where to go is Austin.', 'go'),
#  ("Play golf and rent a ski boat and jet ski's.", 'play'),
#  ('Can you please make sure he has an active password.', 'make'),
#  ('Once the construction drawings are complete I will send them to you for a revised bid.',
#   'send'),
#  ('Jim, Is there going to be a conference call or some type of weekly meeting about all the regulatory issues facing California this week?',
#   'call'),
#  ('Can you make sure the gas desk is included.', 'make'),
#  ('Have him send his resume to Karen Buckley in HR.', 'send'),
#  ('After migration of your mailbox, you will not be able to send or recieve mail via Notes, and you will not be able to start using Outlook until it is configured by the Outlook Migration team the morning after your mailbox is migrated.',
#   'send'),
#  ('During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#   'read'),
#  ('There are future plans to make OWA available from your home or when traveling abroad.',
#   'make'),
#  ("When you finish, simply click on the 'Reply' button then hit 'Send' Your survey will automatically be sent to the Outlook 2000 Migration Mailbox.",
#   'hit'),
#  ('Call me if you did not receive them.', 'call'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ('Can you email or call with some additional insight?', 'call'),
#  ('Basically, can you help us get any clarification on the language "the average daily cost of gas for all delivery points in California"?',
#   'help'),
#  ("Andrea, After reviewing Bryan Hull's resume, I think he would be best suited for the trading track program.",
#   'think'),
#  ('Please call or email with comments.', 'call'),
#  ('Never say never, but I think it is highly unlikely that the final order will contain a fixed price cap.',
#   'think'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ("I don't have my floor plan with me at work today, but will bring in tomorrow and fax you a copy.",
#   'bring'),
#  ('You should be able to simply click on this URL below and it should come up for you.',
#   'come'),
#  ('I think Chad deserves an interview.', 'think'),
#  ('Send his resume to Karen Buckley.', 'send'),
#  ('Have him send his resume to Karen Buckley in HR.', 'send'),
#  ("Andrea, After reviewing Bryan Hull's resume, I think he would be best suited for the trading track program.",
#   'think'),
#  ('In order to make it feasible within my budget I am sure it will take several iterations.',
#   'make'),
#  ('I just want to assure you that I am going to build this house in the fall and I would seriously consider using the panel system if it truly was only a slight increase in cost over stick built.',
#   'build'),
#  ('I will bring handouts.', 'bring'),
#  ('Chad, Call Ted Bland about the trading track program.', 'call'),
#  ('Your experience should help you in the process and make the risk rotation unnecessary.',
#   'help'),
#  ('How am I to send them the money for the silent second?', 'send'),
#  ("I don't see how their bank will make the funds available by Friday unless I wire the money.",
#   'make'),
#  ('If that is what I need to do please send wiring instructions.', 'send'),
#  ('I will bring handouts.', 'bring'),
#  ('In order to make it feasible within my budget I am sure it will take several iterations.',
#   'make'),
#  ('I just want to assure you that I am going to build this house in the fall and I would seriously consider using the panel system if it truly was only a slight increase in cost over stick built.',
#   'build'),
#  ('Please try and schedule the appraiser for sometime after 1 p.m. so my Dad can walk him around.',
#   'walk'),
#  ('I am going to have an architect in Austin draw the plans and help me work up a detailed specification list.',
#   'help'),
#  ('I will send you that detailed plan and spec list when complete for a final bid.',
#   'send'),
#  ('Your intuition as to reductions seen so far (e.g., March 2001 vs. March 2000) was absolutely correct.',
#   'march'),
#  ('Other forecasters (e.g., PIRA) are estimating that another 1,200-1,300 MWa (making total year-on-year reduction = 2,700-2,800) will come off starting in June.',
#   'come'),
#  ('Given that the 6% decrease we have seen so far has come without any real price signals to the retail market, and that rates are now scheduled to increase, I think that it is possible we could see peak demand fall by as much as 10% relative to last year.',
#   'come'),
#  ('Finally, the general economic slowdown in Calif could also further depress demand, or at least make the 3,500 MWa number that much more attainable.',
#   'make'),
#  ('I think it is reasonable to assume that the non-ISO portion of Calif (i.e., LADWP and IID) will see similar reductions in demand.',
#   'think'),
#  ('As you are aware, the Pacific NW has already seen about 2,000 MWa of aluminum smelter load come off since Dec, and this load is expected to stay off at least through Sep, and possibly for the next couple of years (if BPA gets its wish).',
#   'come'),
#  ('While the rest of the WSCC may not see the 10%+ reductions that I am expecting in Calif, I think we could easily expect an additional 2-3% (on top of the 4% already realized), or approx 1,000-1,500 MWa, of further demand reduction in the non-Calif WSCC for this summer.',
#   'think'),
#  ('This would bring the total reduction for the WSCC, including the 2,000 MWa aluminum load we have already seen, to around 6,500-7,000 MWa when compared with last summer.',
#   'bring'),
#  ('Please feel free to call (503-464-8671) if you have any questions or need any further information.',
#   'call'),
#  ("SET is not regulated by the California Public Utilities Commission and you do not have to buy SET's products and services to continue to receive quality regulated service from the utilities.",
#   'buy'),
#  ('As I mentioned I am going to have Cary Kipp draw the plans for the residence and I will get back in touch with you once he is finished.',
#   'touch'),
#  ('I will get back in touch with you once we have made the final determination on unit mix and site plan.',
#   'touch'),
#  ('I think you are right that engaging an architect is the next logical step.',
#   'think'),
#  ('Also, I would like to visit a couple of homes that you have built and speak to 1 or 2 satisfied home owners.',
#   'visit'),
#  ('Are there any homes near completion that I could walk through that day?',
#   'walk'),
#  ('Once I have the plans and specs, I will send them to you so you can adjust your bid.',
#   'send'),
#  ('Do you have a distribution list to send this to all the traders.', 'send'),
#  ('I will bring handouts.', 'bring'),
#  ('Employees who work for business units that are scheduled to move to the new building and currently park in the Allen Center or Met garages are being offered a parking space in the new Enron Center garage.',
#   'move'),
#  ('Spaces will be filled on a first come first served basis.', 'come'),
#  ('Garage stairways next to the elevator lobbies at each floor may be used as an exit in the event of elevator trouble.',
#   'exit'),
#  ('Following your email, arrangements will be made for you to turn in your old parking card and receive a parking transponder along with a new information packet for the new garage.',
#   'turn'),
#  ('(You must enter & exit on Clay St. the first two weeks, also pedestrians, will have to use the garage stairwell located on the corner of Bell & Smith.)',
#   'enter'),
#  ('Call me on my cell phone if you need me.', 'call'),
#  ('What role would you play in obtaining financing?', 'play'),
#  ('I think I need to find a way to get the total cost down to $10,500,000 which would boost the return to 31%.',
#   'think'),
#  ('I will be out of the office for the rest of the week, but I will call you early next week.',
#   'call'),
#  ('A few points that might not be obvious from the plans are: There will be a double porch across the back just like the front No dormers (Metal roof) 1/2 bath under stairs Overall dimensions are 55 by 40 What I am looking for is a little design help in the kitchen.',
#   'help'),
#  ('Reagan suggested that I find a way to make the exterior more attractive.',
#   'make'),
#  ('I am ready to go ahead and have the plans done so I can spec out all the finishings and choose a builder.',
#   'go'),
#  ('A few points that might not be obvious from the plans are: There will be a double porch across the back just like the front No dormers (Metal roof) 1/2 bath under stairs Overall dimensions are 55 by 40 What I am looking for is a little design help in the kitchen.',
#   'help'),
#  ('Reagan suggested that I find a way to make the exterior more attractive.',
#   'make'),
#  ('I am ready to go ahead and have the plans done so I can spec out all the finishings and choose a builder.',
#   'go'),
#  ('A few points that might not be obvious from the plans are: There will be a double porch across the back just like the front No dormers (Metal roof) 1/2 bath under stairs Overall dimensions are 55 by 40 What I am looking for is a little design help in the kitchen.',
#   'help'),
#  ('Reagan suggested that I find a way to make the exterior more attractive.',
#   'make'),
#  ('I am ready to go ahead and have the plans done so I can spec out all the finishings and choose a builder.',
#   'go'),
#  ('A few points that might not be obvious from the plans are: There will be a double porch across the back just like the front No dormers (Metal roof) 1/2 bath under stairs Overall dimensions are 55 by 40 What I am looking for is a little design help in the kitchen.',
#   'help'),
#  ('Reagan suggested that I find a way to make the exterior more attractive.',
#   'make'),
#  ('I am ready to go ahead and have the plans done so I can spec out all the finishings and choose a builder.',
#   'go'),
#  ('Chad, Call Ted Bland about the trading track program.', 'call'),
#  ('Your experience should help you in the process and make the risk rotation unnecessary.',
#   'help'),
#  ('I want to get painfully detailed with the specs before I make a decision but this is a start.',
#   'make'),
#  ('I think I am ready to get plans drawn up.', 'think'),
#  ('I am going to call Cary Kipp to see about setting up a design meeting to see if I like his ideas.',
#   'call'),
#  ('Should I wait until the partnership has been conveyed to sign in the name of the partnership.',
#   'wait'),
#  ('After debt service that would only leave $122K.', 'leave'),
#  ('Talk to you this afternoon.', 'talk'),
#  ('Call me if you have any questions.', 'call'),
#  ('How am I to send them the money for the silent second?', 'send'),
#  ("I don't see how their bank will make the funds available by Friday unless I wire the money.",
#   'make'),
# ...
#   'march'),
#  ('-Robert Scalabrino Northeast Power Prices Fall With More Generation, Less Demand Philadelphia, May 14 (Bloomberg Energy) -- An increase in available generation coupled with less weather-related demand, caused next-day power prices in the Northeast U.S. to fall as much as 11.3 percent this morning, traders said.',
#   'fall'),
#  ('Interconnection data shows 1,675 megawatts returned to service today, and an additional 1,232 megawatts are expected to hit the grid tomorrow.',
#   'hit'),
#  ('"It\'s supposed to be pretty warm in the TVA (Tennessee Valley Authority) area, so everyone is looking to go from Cinergy to there," one East Central Area Reliability Council trader said.',
#   'go'),
#  ('-Brian Whary U.K. Power Prices Fall as Offers Continue to Outweigh Bids London, May 14 (Bloomberg Energy) -- Power prices in the U.K. fell for the fourth consecutive day amid continued heavy selling interest, traders said.',
#   'fall'),
#  ('The contract has fallen around 82 pence since the start of the month amid aggressive selling interest, mainly from one trading house, which intended to buy back contracts where it was short.',
#   'buy'),
#  ('-Amal Halawi Nordic Power Soars in Active Trade on Renewed Buying Interest Lysaker, Norway, May 14 (Bloomberg Energy) -- Longer-term electricity prices on the Nordic Power Exchange in Lysaker, Norway, soared in active afternoon trade after participants rushed to buy seasonal contracts in an attempt to close positions amid limited hydro-supply, traders said.',
#   'buy'),
#  ('Please send ASAP.', 'send'),
#  ("When you finish, simply click on the 'Reply With History' button then hit 'Send'  Your survey will automatically be sent to the Outlook 2000 Migration Mailbox.",
#   'hit'),
#  ('If the negotiations stall, it seems like I need to go ahead and cut off the utilities.',
#   'go'),
#  ('Hopefully things will go smoothly.', 'go'),
#  ('WHEN:  Friday, May 18 TIME:   10:00 am - 3:00 pm - lunch will be provided WHERE:  Enron Building, 8C1 (8th floor) A video conference is being organized to enable broad participation from the London office and a teleconference will be set up for others who would like to call in.',
#   'call'),
#  ('Can you guys coordinate to make sure someone listens to this conference call each week.',
#   'call'),
#  ('Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Please forward to anyone on your team that wants updates on Western wholesale matters (should also give you an opportunity to raise state matters if you want to discuss).',
#   'call'),
#  ("Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Date:   Every Thursday Time:    1:00 pm Pacific, 3:00 pm Central, and 4:00 pm Eastern time, Number:   1-888-271-0949, Host Code:  661877, (for Jim only), Participant Code: 936022, (for everyone else), Attached is the table of the on-going FERC issues and proceedings updated for use on tomorrow's conference call.",
#   'call'),
#  ('I will be unable to participate in the call tomorrow as I will be attending the Senate Energy and Resource Committee Hearing on the elements of the FERC market monitoring and mitigation order.',
#   'call'),
#  ('Bridge Loan Financing Bills May Not Meet Their May 8th Deadline Due to Lack of Support Sources report there will not be a vote regarding the authorization for the bond issuance/bridge loan by the May 8th deadline.',
#   'vote'),
#  ("Sources report that the Republicans intend to hold out for full disclosure of the governor's plan for handling the crisis, including the details and terms of all long-term contracts he has negotiated, before they will support the bond issuance to go forward.",
#   'go'),
#  ('According to sources close to the Republicans in  the legislature, Republicans do not believe there should be a bridge loan due to money available in the General Fund.',
#   'close'),
#  ('The Republicans intend to bring this up in debate on  Monday.', 'bring'),
#  ('Transwestern Pipeline Co. posted new notice(s) since our last check at 12/12/2000 12:18:01 PM, the newest notice looks like: Capacity Constraint, Dec 12 2000 12:25PM, Dec 13 2000  9:00AM, Dec 14 2000 8:59AM, 2231, Allocation - SOCAL NEEDLES Please click the following to go to the web site for detail.',
#   'go'),
#  ('Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Please forward to anyone on your team that wants updates on Western wholesale matters (should also give you an opportunity to raise state matters if you want to discuss).',
#   'call'),
#  ("Call Privileged & Confidential Communication Attorney-Client Communication and Attorney Work Product Privileges Asserted Date:   Every Thursday Time:    1:00 pm Pacific, 3:00 pm Central, and 4:00 pm Eastern time, Number:   1-888-271-0949, Host Code:  661877, (for Jim only), Participant Code: 936022, (for everyone else), Attached is the table of the on-going FERC issues and proceedings updated for use on tomorrow's conference call.",
#   'call'),
#  ('I will be unable to participate in the call tomorrow as I will be attending the Senate Energy and Resource Committee Hearing on the elements of the FERC market monitoring and mitigation order.',
#   'call'),
#  ('As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#   'think'),
#  ('My suggestion for where to go is Austin.', 'go'),
#  ("Play golf and rent a ski boat and jet ski's.", 'play'),
#  ('Can you please make sure he has an active password.', 'make'),
#  ('Once the construction drawings are complete I will send them to you for a revised bid.',
#   'send'),
#  ('Jim, Is there going to be a conference call or some type of weekly meeting about all the regulatory issues facing California this week?',
#   'call'),
#  ('Can you make sure the gas desk is included.', 'make'),
#  ('After migration of your mailbox, you will not be able to send or recieve mail via Notes, and you will not be able to start using Outlook until it is configured by the Outlook Migration team the morning after your mailbox is migrated.',
#   'send'),
#  ('During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#   'read'),
#  ('There are future plans to make OWA available from your home or when traveling abroad.',
#   'make'),
#  ("When you finish, simply click on the 'Reply' button then hit 'Send' Your survey will automatically be sent to the Outlook 2000 Migration Mailbox.",
#   'hit'),
#  ('Call me if you did not receive them.', 'call'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ('From:  Phillip K Allen                           12/12/2000 12:03 PM  To: Christi L Nicolay/HOU/ECT@ECT cc: Subject: Talking points about California Gas market Christy, I read these points and they definitely need some touch up.',
#   'read'),
#  ("On the gas side, I think Kean/Lay need an update to a table you prepared for me a few months ago, which I've attached..  Can you oblige?",
#   'think'),
#  ('Send to Karen Buckley.', 'send'),
#  ('Can you email or call with some additional insight?', 'call'),
#  ('Basically, can you help us get any clarification on the language "the average daily cost of gas for all delivery points in California"?',
#   'help'),
#  ('Please call or email with comments.', 'call'),
#  ('Never say never, but I think it is highly unlikely that the final order will contain a fixed price cap.',
#   'think'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ('Is there the potential for a surprise announcement of some sort of fixed price gas or power cap once the open meeting finally happens?',
#   'open'),
#  ("I don't have my floor plan with me at work today, but will bring in tomorrow and fax you a copy.",
#   'bring'),
#  ('Christy, I read these points and they definitely need some touch up.',
#   'read'),
#  ('You should be able to simply click on this URL below and it should come up for you.',
#   'come'),
#  ('Send his resume to Karen Buckley.', 'send'),
#  ('Have him send his resume to Karen Buckley in HR.', 'send'),
#  ("Andrea, After reviewing Bryan Hull's resume, I think he would be best suited for the trading track program.",
#   'think'),
#  ('I think Chad deserves an interview.', 'think'),
#  ("In our special Holidays section, you'll find reviews of holiday films, buying guides from our technology experts at Circuits to help you find computers and electronics, our special holiday Book Review issue, information on travel in the snow or sun, and fun ways to entertain the kids while they're home on vacation.",
#   'help'),
#  ('http://www.nytimes.com/pages/holidays/?1213c Elsewhere on the site you can send your friends and family NYTimes.com e-greeting cards featuring holiday photos from The New York Times Photo Archives, and download a new holiday screensaver that includes ten photographs from The Times celebrating the magical season in the city.',
#   'send'),
#  ('http://nytimes.abuzz.com/interaction/s.124643/discussion/e/1.162 And at WineToday.com, you\'ll find the "Holiday & Vine Food and Wine Guide," to help you plan your holiday meals.',
#   'help'),
#  ("Bring today's news to your family table /--------------------advertisement----------------------\\ Exclusive Travel Opportunities from Away.com.",
#   'bring'),
#  ("Bring today's news to your family's table ------ Conversation Starters, the newest feature of the Learning Network, helps parents discuss the day's news with their children.",
#   'bring'),
#  ("We hope you'll make a point of visiting us today and every day.", 'make'),
#  ('ABOUT THIS E-MAIL ------------------------------------- Your registration to NYTimes.com included permission to send you information about new features and services.',
#   'send'),
#  ('To unsubscribe from future mailings, visit: http://www.nytimes.com/unsubscribe To change your e-mail address, please go to our help center: http://www.nytimes.com/help Suggestions and feedback are welcome at feedback@nytimes.com.',
#   'go'),
#  ('In order to make it feasible within my budget I am sure it will take several iterations.',
#   'make'),
#  ('I just want to assure you that I am going to build this house in the fall and I would seriously consider using the panel system if it truly was only a slight increase in cost over stick built.',
#   'build'),
#  ('Please call me later today.', 'call'),
#  ('I will bring handouts.', 'bring'),
#  ('Chad, Call Ted Bland about the trading track program.', 'call'),
#  ('Your experience should help you in the process and make the risk rotation unnecessary.',
#   'help'),
#  ('How am I to send them the money for the silent second?', 'send'),
#  ("I don't see how their bank will make the funds available by Friday unless I wire the money.",
#   'make'),
#  ('If that is what I need to do please send wiring instructions.', 'send'),
#  ('I will bring handouts.', 'bring'),
#  ('Please try and schedule the appraiser for sometime after 1 p.m. so my Dad can walk him around.',
#   'walk'),
#  ('I WILL TALK TO LUTZ ABOUT HIS SHARE OF THE LEGAL BILLS.', 'talk'),
#  ('ENTER THE INFO.', 'enter'),
#  ('I will send a check for $250.', 'send'),
#  ("I don't think I received it.", 'think'),
#  ('I am going to have an architect in Austin draw the plans and help me work up a detailed specification list.',
#   'help'),
#  ('I will send you that detailed plan and spec list when complete for a final bid.',
#   'send'),
#  ('Your intuition as to reductions seen so far (e.g., March 2001 vs. March 2000) was absolutely correct.',
#   'march'),
#  ('Other forecasters (e.g., PIRA) are estimating that another 1,200-1,300 MWa (making total year-on-year reduction = 2,700-2,800) will come off starting in June.',
#   'come'),
#  ('Given that the 6% decrease we have seen so far has come without any real price signals to the retail market, and that rates are now scheduled to increase, I think that it is possible we could see peak demand fall by as much as 10% relative to last year.',
#   'come'),
#  ('Finally, the general economic slowdown in Calif could also further depress demand, or at least make the 3,500 MWa number that much more attainable.',
#   'make'),
#  ('I think it is reasonable to assume that the non-ISO portion of Calif (i.e., LADWP and IID) will see similar reductions in demand.',
#   'think'),
#  ('As you are aware, the Pacific NW has already seen about 2,000 MWa of aluminum smelter load come off since Dec, and this load is expected to stay off at least through Sep, and possibly for the next couple of years (if BPA gets its wish).',
#   'come'),
#  ('While the rest of the WSCC may not see the 10%+ reductions that I am expecting in Calif, I think we could easily expect an additional 2-3% (on top of the 4% already realized), or approx 1,000-1,500 MWa, of further demand reduction in the non-Calif WSCC for this summer.',
#   'think'),
#  ('This would bring the total reduction for the WSCC, including the 2,000 MWa aluminum load we have already seen, to around 6,500-7,000 MWa when compared with last summer.',
#   'bring'),
#  ('Please feel free to call (503-464-8671) if you have any questions or need any further information.',
#   'call'),
#  ('We are planning to come to San Marcos for New Years.', 'come'),
#  ("SET is not regulated by the California Public Utilities Commission and you do not have to buy SET's products and services to continue to receive quality regulated service from the utilities.",
#   'buy'),
#  ('As I mentioned I am going to have Cary Kipp draw the plans for the residence and I will get back in touch with you once he is finished.',
#   'touch'),
#  ('I will get back in touch with you once we have made the final determination on unit mix and site plan.',
#   'touch'),
#  ('I think you are right that engaging an architect is the next logical step.',
#   'think'),
#  ('Also, I would like to visit a couple of homes that you have built and speak to 1 or 2 satisfied home owners.',
#   'visit'),
#  ('Are there any homes near completion that I could walk through that day?',
#   'walk'),
#  ('Once I have the plans and specs, I will send them to you so you can adjust your bid.',
#   'send'),
#  ('Do you have a distribution list to send this to all the traders.', 'send'),
#  ('Employees who work for business units that are scheduled to move to the new building and currently park in the Allen Center or Met garages are being offered a parking space in the new Enron Center garage.',
#   'move'),
#  ('Spaces will be filled on a first come first served basis.', 'come'),
#  ('Garage stairways next to the elevator lobbies at each floor may be used as an exit in the event of elevator trouble.',
#   'exit'),
#  ('Following your email, arrangements will be made for you to turn in your old parking card and receive a parking transponder along with a new information packet for the new garage.',
#   'turn'),
#  ('(You must enter & exit on Clay St. the first two weeks, also pedestrians, will have to use the garage stairwell located on the corner of Bell & Smith.)',
#   'enter'),
#  ('Call me on my cell phone if you need me.', 'call'),
#  ('What role would you play in obtaining financing?', 'play'),
#  ('I think I need to find a way to get the total cost down to $10,500,000 which would boost the return to 31%.',
#   'think'),
#  ('I will be out of the office for the rest of the week, but I will call you early next week.',
#   'call'),
#  ('A few points that might not be obvious from the plans are: There will be a double porch across the back just like the front No dormers (Metal roof) 1/2 bath under stairs Overall dimensions are 55 by 40 What I am looking for is a little design help in the kitchen.',
#   'help'),
#  ('Reagan suggested that I find a way to make the exterior more attractive.',
#   'make'),
#  ...]
