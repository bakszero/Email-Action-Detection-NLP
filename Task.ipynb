# %% [markdown]
# # Actionable Email Item Detection

# %%
import numpy as np
import pandas as pd
import re

import nltk

# %%
# Dataset directory, set this before your experiments
dataset = '/home/syed.b/emails.csv'

# %%
# Pick a sample for understanding perspective
df_sample  = pd.read_csv(dataset, skiprows = lambda x : np.random.rand() > 0.01 and x > 0)

# %%
df_sample.shape
# Out:
# (5148, 2)

# %%
df_sample['message'][0]
# Out:
# "Message-ID: <2068674.1075855691152.JavaMail.evans@thyme>\nDate: Tue, 25 Apr 2000 05:22:00 -0700 (PDT)\nFrom: phillip.allen@enron.com\nTo: hargr@webtv.net\nSubject: Re: #30\nMime-Version: 1.0\nContent-Type: text/plain; charset=us-ascii\nContent-Transfer-Encoding: 7bit\nX-From: Phillip K Allen\nX-To: hargr@webtv.net (Neal Hargrove) @ ENRON\nX-cc: \nX-bcc: \nX-Folder: \\Phillip_Allen_Dec2000\\Notes Folders\\'sent mail\nX-Origin: Allen-P\nX-FileName: pallen.nsf\n\n2000-1969=31"

# %%
# Establish cleaning patterns

[ x.strip() for x in df_sample['message'][11].split('FileName:')[1].split('\n',1)[1].strip('\n').split('\n') if x]
# Out:
# ['---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/30/2000',
#  '09:14 AM ---------------------------',
#  '',
#  '',
#  'Enron Technology',
#  '',
#  'From:  Stephen Stock                           10/27/2000 12:49 PM',
#  '',
#  'To: Phillip K Allen/HOU/ECT@ECT',
#  'cc:',
#  'Subject: ERMS / RMS Databases',
#  'Phillip,',
#  'It looks as though we have most of the interim hardware upgrades in the',
#  'building now, although we are still expecting a couple of components to',
#  'arrive on Monday.',
#  'The Unix Team / DBA Team and Applications team expect to have a working test',
#  "server environment on Tuesday. If anything changes, I'll let you know.",
#  'best regards',
#  'Steve Stock']

# %%
# Load the whole data

df = pd.read_csv(dataset)

# %%
df.shape
# Out:
# (517401, 2)

# %%
# Store emails here in the list
# Use nltk's sentence tokenizer to tokenize the email sentences -- since we notice above that 
# order
emails = []

for i in range(df.shape[0]):
    
    emails.append(nltk.sent_tokenize(' '.join([ x.strip() for x in df['message'][i].split('FileName:')[1].split('\n',1)[1].strip('\n').split('\n') if x]
)))

# %%
#Sanity check
emails[1]
# Out:
# ['Traveling to have a business meeting takes the fun out of the trip.',
#  'Especially if you have to prepare a presentation.',
#  'I would suggest holding the business plan meetings here then take a trip without any formal business meetings.',
#  'I would even try and get some honest opinions on whether a trip is even desired or necessary.',
#  'As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#  'Too often the presenter speaks and the others are quiet just waiting for their turn.',
#  'The meetings might be better if held in a round table discussion format.',
#  'My suggestion for where to go is Austin.',
#  "Play golf and rent a ski boat and jet ski's.",
#  'Flying somewhere takes too much time.']

# %% [markdown]
# ## First Filter
#
#
# Check for action words. A curated list of action words is specified and if our sentences from the emails contain one of these words, we store it for a further filtering process.
#
# The action words file is in the current directory as this Jupyter Notebook.

# %%
# Read in action verbs
action_verbs = []

with open('./action_words.txt', 'r') as f:
    for line in f:
        action_verbs.append(line.strip().lower())
        
        
# Storing the actionable items as a tuple of 3 items - (text, action-words, no. of action-words in sentence)
action_texts = []   

# Due to memory/time constraints, we do not read in the entire emails, rather take a subset of 1,00,000 to show results 
for item in emails[:100000]:
    for text in item:
        temp_verb_list = []
        
        for verb in action_verbs:
            if verb in text.lower().split():
                temp_verb_list.append(verb)
        if len(temp_verb_list) > 0:
            action_texts.append((text, temp_verb_list, len(temp_verb_list)))

# %%
action_texts[:20]
# Out:
# [('As far as the business meetings, I think it would be more productive to try and stimulate discussions across the different groups about what is working and what is not.',
#   ['think'],
#   1),
#  ('My suggestion for where to go is Austin.', ['go', 'suggestion'], 2),
#  ("Play golf and rent a ski boat and jet ski's.", ['play'], 1),
#  ('Randy, Can you send me a schedule of the salary and level of everyone in the scheduling group.',
#   ['send'],
#   1),
#  ('Please cc the following distribution list with updates: Phillip Allen (pallen@enron.com) Mike Grigsby (mike.grigsby@enron.com) Keith Holst (kholst@enron.com) Monique Sanchez Frank Ermis John Lavorato Thank you for your help Phillip Allen',
#   ['help'],
#   1),
#  ("1. login:  pallen pw: ke9davis I don't think these are required by the ISP 2.  static IP address IP: 64.216.90.105 Sub: 255.255.255.248 gate: 64.216.90.110 DNS: 151.164.1.8 3.",
#   ['think'],
#   1),
#  ('kWh deal must have limited/ > no risk forward gas price to make deal work.',
#   ['make'],
#   1),
#  ('> > For 6-8 hours a day  Microturbine run time: > Gas requirement for 180 microturbines 227 - 302 MMcf per year > Gas requirement for 240 microturbines 302 - 403 MMcf per year > > Gas will likely be consumed from May through September, during peak > electric period.',
#   ['run'],
#   1),
#  ('> > Should you have additional questions, give me a call.', ['give'], 1),
#  ('Lucy, Here are the rentrolls: Open them and save in the rentroll folder.',
#   ['open'],
#   1),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/09/2000 02:16 PM --------------------------- Richard Burchfield 10/06/2000 06:59 AM To: Phillip K Allen/HOU/ECT@ECT cc: Beth Perlman/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list Phillip, Below is the issues & to do list as we go forward with documenting the requirements for consolidated physical/financial positions and transport trade capture.',
#   ['go'],
#   1),
#  ('Throughout the meeting on Wednesday, Keith alluded to the inability to get consensus amongst the traders on the presentation of the consolidated position, so the solution was to make it so that a trader can arrange the position screen to their liking (much like Excel).',
#   ['make'],
#   1),
#  ("Richard ---------------------- Forwarded by Richard Burchfield/HOU/ECT on 10/06/2000 08:34 AM --------------------------- Allan Severude 10/05/2000 06:03 PM To: Richard Burchfield/HOU/ECT@ECT cc: Peggy Alix/HOU/ECT@ECT, Russ Severson/HOU/ECT@ECT, Scott Mills/HOU/ECT@ECT, Kenny Ha/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list From our initial set of meetings with the traders regarding consolidated positions, I think we still have the following issues: We don't have a single point of contact from the trading group.",
#   ['think'],
#   1),
#  ('We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#   ['come', 'help'],
#   2),
#  ("Things left to do: I think it may be useful to try to formulate a high level project goal to make it as clear as possible what we're trying to accomplish with this project.",
#   ['make', 'think'],
#   2),
#  ("It'll help determine which requests fall under the project scope.",
#   ['help'],
#   1),
#  ('Go through the list of requests to determine which are in scope for this project and which fall out of scope.',
#   ['go'],
#   1),
#  ('---------------------- Forwarded by Phillip K Allen/HOU/ECT on 10/09/2000 02:00 PM --------------------------- Richard Burchfield 10/06/2000 06:59 AM To: Phillip K Allen/HOU/ECT@ECT cc: Beth Perlman/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list Phillip, Below is the issues & to do list as we go forward with documenting the requirements for consolidated physical/financial positions and transport trade capture.',
#   ['go'],
#   1),
#  ('Throughout the meeting on Wednesday, Keith alluded to the inability to get consensus amongst the traders on the presentation of the consolidated position, so the solution was to make it so that a trader can arrange the position screen to their liking (much like Excel).',
#   ['make'],
#   1),
#  ("Richard ---------------------- Forwarded by Richard Burchfield/HOU/ECT on 10/06/2000 08:34 AM --------------------------- Allan Severude 10/05/2000 06:03 PM To: Richard Burchfield/HOU/ECT@ECT cc: Peggy Alix/HOU/ECT@ECT, Russ Severson/HOU/ECT@ECT, Scott Mills/HOU/ECT@ECT, Kenny Ha/HOU/ECT@ECT Subject: Consolidated positions: Issues & To Do list From our initial set of meetings with the traders regarding consolidated positions, I think we still have the following issues: We don't have a single point of contact from the trading group.",
#   ['think'],
#   1)]

# %% [markdown]
# ## Hierarchical Filters
#
# **NOTE**: This section is applicable when we want to achieve high precision i.e. we might miss a few action items from the original list but we will achieve high accuracy on whatever has been retrieved.
#
# ### First Level:
#
# **Filter A**: Check if no. of action words are more than 1 and if length of email sentence is less than 30.
#
#
# ### Second Level:
#
# **Filter B**: Check if object pronouns or subject pronouns are present in the sentence. The list is specified as below.
#
#
# ### Third Level:
#
#
# **Filter C**: Disregard those with negation words.

# %%
# Filters A,B,C:

object_pronouns = ['me', 'her', 'him', 'us', 'them']
subject_pronouns = ['i', 'we', 'you', 'he', 'she', 'they']
negation_words = ["shouldn't", "couldn't", "wouldn't"]

filtered_action_texts = []

for item in action_texts:
    if item[2]>1 and len(item[0].split())<30:
        
        
    
        obj_flag =0 
        for x in object_pronouns:
            if x in item[0].lower().split(): 
                filtered_action_texts.append(item[0])
                obj_flag =1
                break
        if (obj_flag == 0):
            for x in subject_pronouns:
                if x in item[0].lower().split():
                    filtered_action_texts.append(item[0])
                    break

final_action_texts = []
for item in filtered_action_texts:
    #print (item)
    count_neg = 0
    for x in negation_words:
        if x in item.lower().split():
            count_neg += 1
            continue
    if count_neg == 0:
        final_action_texts.append(item)

# %%
final_action_texts
# Out:
# ['We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Phillip, I will call you today to go over this more thoroughly.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'During this period, you can use Outlook Web Access (OWA) via your= web browser (Internet Explorer 5.0) to read and send mail.',
#  'When you open the file, go to the "Checkbook" tab and look at the yellow highlighted items.',
#  "I will read it this weekend and ask my dad about the a/c's.",
#  'What do you think about being open until noon on Saturday.',
#  'I would like to dust off my road bike and go for a ride some Saturday.',
#  'I think my folks are ready to start building.',
#  'I think Steven Wolf is the person to talk to about moving Kim Olinger to a different RC code.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#  'Your experience should help you in the process and make the risk rotation unnecessary.',
#  'Your experience should help you in the process and make the risk rotation unnecessary.',
#  "I don't think we should make him pay late fees if can't communicate clearly.",
#  "Please give me a call when you have time, and I'll explain the old BiOp / new BiOp issue.",
#  'Christy, I read these points and they definitely need some touch up.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I would like to come and visit you again this month.',
#  'Jeff, Before you write off the stage, a few things to think about.',
#  'Write me a note about what is going on and what issues you need my help to deal with when you send the rentroll.',
#  'Give him a call and he will fill you in on the details of the program.',
#  'His number is 713-781-5810, if you want to call him and send the documents to him directly.',
#  'Wait until you have copies of the bills and the letter before you start collecting.',
#  'IF THIS IS A PROBLEM TO DO IT THIS WAY PLEASE CALL ME AND I WILL WALK PHILLIP THROUGH THE STEPS TO APPROVE.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'FREE E-newsletters from Redherring.com provide more answers, analysis and opinion to help you make more strategic investing decisions.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Phillip, I will call you today to go over this more thoroughly.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'When you open the file, go to the "Checkbook" tab and look at the yellow highlighted items.',
#  "I will read it this weekend and ask my dad about the a/c's.",
#  'What do you think about being open until noon on Saturday.',
#  'I would like to dust off my road bike and go for a ride some Saturday.',
#  'I think my folks are ready to start building.',
#  'I think Steven Wolf is the person to talk to about moving Kim Olinger to a different RC code.',
#  'Please give me a call - 503-805-2117.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#  'Christy, I read these points and they definitely need some touch up.',
#  'Your experience should help you in the process and make the risk rotation unnecessary.',
#  'Nicole is not leaving to go to a competitor, but is going to spend more time with her family.',
#  'I will probably want Nicole and Theresa to come to Houston one more time to sit with us and the logistics team, maybe in early May.',
#  "I don't think we should make him pay late fees if can't communicate clearly.",
#  "Please give me a call when you have time, and I'll explain the old BiOp / new BiOp issue.",
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I would like to come and visit you again this month.',
#  'Jeff, Before you write off the stage, a few things to think about.',
#  'Write me a note about what is going on and what issues you need my help to deal with when you send the rentroll.',
#  'Give him a call and he will fill you in on the details of the program.',
#  'His number is 713-781-5810, if you want to call him and send the documents to him directly.',
#  'Wait until you have copies of the bills and the letter before you start collecting.',
#  'IF THIS IS A PROBLEM TO DO IT THIS WAY PLEASE CALL ME AND I WILL WALK PHILLIP THROUGH THE STEPS TO APPROVE.',
#  'I will do my best to provide answers and talk about where we go from here.',
#  "We'll also highlight the key matchups i= n every NFL game to  help you decide who to start and who to bench.",
#  'Please contact Janice Riedel at X-37507 or Cathy Phillips at X-36898 to sign up as a walker, make a donation, or ask any questions you may have.',
#  "I don't think anything has changed, but I want to make sure that the version of the Deed you sign is the latest version.",
#  "I don't think anything has changed, but I want to make sure that the version of the Deed you sign is the latest version.",
#  'Give me a call when you have a chance.',
#  'Should I go with Shaun Alexander or 3 WRs and start Marty  Booker?',
#  'It is difficult to sit Thomas  after the breakout game he had last week, but he will face a  respectable run defense.',
#  "If you're in a Football Commissioner league, go to Schedule, Playoffs to see when your playoffs start and how many rounds they last.",
#  'In addition to our monthly  newsl= etter, we occasionally send Special Edition newsletters with  information o= n new vehicles that we think will interest you.',
#  'Then you could close off the existing play room to replace the bedroom lost.',
#  "http://cgi.zdnet.com/slink?/adeskb/adt1120/2825838:8593142 # _____________________NEWS ANALYSIS_____________________ Sylvia Carr APPLE: BRING ON XP... HP'S SPEED BOOST... PENTAGON GOING PRIVATE... Might you Windows users come back to the Mac?",
#  'I will then expect my group to contact you before they leave at night if it is above or below your estimates, or range you give them.',
#  'Give me a call anytime today.',
#  'Give me a call or drop me  an email when you have a chance at 936-321-6307 or let me know when is a good  time to call you.',
#  'shows you five useful sites that can help you make the most of the season.',
#  "They'll give you songs to sing and stories to read, and even show you how to send last-minute holiday cards.",
#  'Also,  I do not think Accenture will want to enter into partnership structure with a ghost company unless we get Dinergy involved.',
#  'Also,  I will ask them to cut the meeting by 10 min, thus we can go over the documents and can answer your questions.',
#  'Preston shows you how to take control of your hectic schedule with programs that manage your appointments, contacts, and gift lists, and even help you send out holiday cards.',
#  'Should you receive this message, please call our Computer Department and ask for either myself (Howard Gordon) @ 830-401-1185, Christina Kirby @ 830-401-1189, or Lora Robles @ 830-401-1182.',
#  'If you reach our voice mail (or another employee), please leave your Name, Account # and call back #.',
#  "We're scheduled for our weekly call tomorrow but if anything comes up just give me a buzz!",
#  'FIX UP YOUR CLUNKER FOR UNDER $50 Sure, if you have a need for speed, you could buy a new PC.',
#  'In addition to our monthly  newsle= tter, we occasionally send Special Edition newsletters with  information on= new vehicles that we think will interest you.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Phillip, I will call you today to go over this more thoroughly.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'Christy, I read these points and they definitely need some touch up.',
#  'Please give me a call - 503-805-2117.',
#  'FREE E-newsletters from Redherring.com provide more answers, analysis and opinion to help you make more strategic investing decisions.',
#  'Wait until you have copies of the bills and the letter before you start collecting.',
#  'His number is 713-781-5810, if you want to call him and send the documents to him directly.',
#  'Write me a note about what is going on and what issues you need my help to deal with when you send the rentroll.',
#  'I would like to come and visit you again this month.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  "Please give me a call when you have time, and I'll explain the old BiOp / new BiOp issue.",
#  "I don't think we should make him pay late fees if can't communicate clearly.",
#  'During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'What do you think about being open until noon on Saturday.',
#  'When you open the file, go to the "Checkbook" tab and look at the yellow highlighted items.',
#  'I think checks out of Bishops Corner, L.P. may be the easiest, or you can wire money to me and I can write the checks when needed.',
#  'If you would like, we can set up a conference call with you, myself, and Larry to go over the payment methodology.',
#  'Should you receive this message, please call our Computer Department and ask for either myself (Howard Gordon) @ 830-401-1185, Christina Kirby @ 830-401-1189, or Lora Robles @ 830-401-1182.',
#  'If you reach our voice mail (or another employee), please leave your Name, Account # and call back #.',
#  "We're scheduled for our weekly call tomorrow but if anything comes up just give me a buzz!",
#  'Should you receive this message, please call our Computer Department and ask for either myself (Howard Gordon) @ 830-401-1185, Christina Kirby @ 830-401-1189, or Lora Robles @ 830-401-1182.',
#  'If you reach our voice mail (or another employee), please leave your Name, Account # and call back #.',
#  'FREE E-newsletters from Redherring.com provide more answers, analysis and opinion to help you make more strategic investing decisions.',
#  'Please give me a call - 503-805-2117.',
#  'I lent the partnership the cash to buy the land with the intent of working with the developer to build a multifamily project.',
#  'Can you ask her to put a stop on her 1st check and send me another (net of any costs for the stop payment).',
#  'Can you ask her to put a > stop on her 1st check and send me another (net of any costs for the stop > payment).',
#  'If you want to give it a try, go to their website at  www.tbarmcamps.org/index.shtml <http://www.tbarmcamps.org/index.shtml> .',
#  'I have jury duty Monday and will call you Tuesday to touch base.',
#  'Jeff Dasovich will give us a status report on these issues and we then discuss where to go from there.',
#  'Jeff Dasovich will give us a status report on these issues and we then discuss where to go from there.',
#  "Let's go for lunch or drinks, it is on Truequote, so bring couple of people if you want, buyt keep it small so we can catch up.",
#  'If you have any questions, please give me a call at 3-5810.',
#  'If you have any questions, please give me a call at x37960.',
#  'Jean, Please have Melissa send down the CD or give me a call and I will come get it.',
#  'Give me a call and let me know how things are going.',
#  "I don't think anything has changed, but I want to make sure that the version of the Deed you sign is the latest version.",
#  'I will give you a call on Tuesday morning.',
#  'I will make the revisions and call you.',
#  'Also,  I do not think Accenture will want to enter into partnership structure with a ghost company unless we get Dinergy involved.',
#  'Also,  I will ask them to cut the meeting by 10 min, thus we can go over the documents and can answer your questions.',
#  'If you would like, we can set up a conference call with you, myself, and Larry to go over the payment methodology.',
#  'Then you could close off the existing= play room to replace the bedroom lost.',
#  'Also,  I will ask them to cut the meeting by 10 min, thus we can go over the documents and can answer your questions.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'If you would like, we can set up a conference call with you, myself, and Larry to go over the payment methodology.',
#  'During this period, you can use Outlook Web Access (OWA) via your= web browser (Internet Explorer 5.0) to read and send mail.',
#  'Your experience should help you in the process and make the risk rotation unnecessary.',
#  'However, the official zoning designation has not been done yet and may not be approved until around the 1st of Aug.  Give me a call when you get back.',
#  'Please make this change and call me back this morning.',
#  'When you open the file, go to the "Checkbook" tab and look at the yellow highlighted items.',
#  "I will read it this weekend and ask my dad about the a/c's.",
#  'What do you think about being open until noon on Saturday.',
#  'I would like to dust off my road bike and go for a ride some Saturday.',
#  'I think my folks are ready to start building.',
#  'I think Steven Wolf is the person to talk to about moving Kim Olinger to a different RC code.',
#  'Christy, I read these points and they definitely need some touch up.',
#  'Can you guys coordinate to make sure someone listens to this conference call each week.',
#  'During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#  'Your experience should help you in the process and make the risk rotation unnecessary.',
#  "I don't think we should make him pay late fees if can't communicate clearly.",
#  "Please give me a call when you have time, and I'll explain the old BiOp / new BiOp issue.",
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I increased your pay last year very quickly so you could make ends meet but I think your wages equate to $10/hr and that is fair.',
#  'I will talk to you later or you can email or call over the weekend.',
#  'I would like to come and visit you again this month.',
#  'Jeff, Before you write off the stage, a few things to think about.',
#  'Write me a note about what is going on and what issues you need my help to deal with when you send the rentroll.',
#  'Give him a call and he will fill you in on the details of the program.',
#  'His number is 713-781-5810, if you want to call him and send the documents to him directly.',
#  'Wait until you have copies of the bills and the letter before you start collecting.',
#  'IF THIS IS A PROBLEM TO DO IT THIS WAY PLEASE CALL ME AND I WILL WALK PHILLIP THROUGH THE STEPS TO APPROVE.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'We really need a single point of contact to help drive the trader requirements and help come to a consensus regarding the requirements.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  'Phillip, I will call you today to go over this more thoroughly.',
#  'Please get back to me as soon as your schedule permits regarding the site visit and feel free to call at any time.',
#  "slafontaine@globalp.com on 10/13/2000 09:42:43 AM To: jarnold@enron.com cc: Subject: mkts cmon give me some credit-you think ive been doing this this long w/out know who's doing what!",
#  'Give me a call or email me and let me know when you have a second or two.',
#  'I would argue that technology will make open outcry exchanges extinct.',
#  'One yelled at Rappaport... "Why don\'t you take your million dollar bonus and go buy Enron stock"',
#  'If you have any difficulty opening or using the file, please write to me or give me a call.',
#  'If you have any difficulty opening or using the file, please write to me or give me a call.',
#  'However, this market needs another 1-2 weeks of what I would  call horizontal price action to set the stage for a big move to the  upside.',
#  'However, this market needs another 1-2 weeks of what I would  call horizontal price action to set the stage for a big move to the  upside.',
#  'I can sit down with you when I am down there to discuss and give you an update of who we are planning to trade with.',
#  'Russell: I think I should give you a little background on small ventures.',
#  'I think about that every time I go there.... Take care and make money!',
#  'Jeff had also asked that you spend some time with him so that a decision could be made as to whether or not to make him an offer.',
#  'I think about that every time I go there.... Take care and make money!',
#  'Dave: A couple things about the limit orders: 1:  When a customer opens up the limit order box, I think the time open should default to 12 hours.',
#  'I think we would bring him as an associate with the hope that he would move up to manager in 6 months.',
#  'I think about that every time I go there.... Take care and make money!',
#  "Hope things are going  well... can't wait for football... lemme know when  you boys come back out here... Andy",
#  "Call me when ready and I'll come collect or send to EB2801e.",
#  'In this case I think 100 is necessary because once a strike has open interest, we must continue to support it.',
#  'Whereas if someone buys the 3085 straddle and the market moves to 3200, they have to call ENE to close the trade.',
#  'I would love to sit down and visit with you for about 30 minutes in the early part of December.',
#  'John, Do you think we need to see about sending an IT Tech for you and Maggi on Friday to make sure everything is working okay?',
#  'i think the velocity of the down move will be much less severe from here.',
#  'think a lot of spec shorts are looking to take profits as we get close to the psychological 400 target.',
#  'It may help if you give specific positions that interest you most as Enron is such a big place, it will help focus the resume to the right people.',
#  'Thanks for your help and please call me with any questions.',
#  'call me if you want to talk further.... thanks for the article.',
#  'call me if you want to talk further.... thanks for the article.',
#  'residential conservation i think is underestimated and has a severe lag effect that will not come back as prices fall.',
#  'I might give him a call - he may be expensive - they had their own boat.',
#  'I might give him a call - he may be expensive - they had their own boat.',
#  'give me a call soon to  dicuss how to most effectively use the line.',
#  'I think I need to move back...',
#  'if you want to discuss further give me a call 4-6 pm houston time.',
#  "Think about what you want to do, and I'll call you tonight to discuss: Do you want to spend the long weekend with me or do your own thing?",
#  'If you want to spend it with me, would you rather go to the beach or to NYC?',
#  "when we get into injections, i think we'll see a big push down.",
#  'i think we close the y on y gap still significantly but im starting to question how when,how much and how long prices come off in apr-jun?',
#  "when we get into injections, i think we'll see a big push down.",
#  "however i think when the picture becomes clearer (i.e.-when we start beating last year's injections by 20 bcf a week), trade will get short.",
#  'i think we close the y on y gap still significantly but im starting to question how when,how much and how long prices come off in apr-jun?',
#  '"Whenever you turn a pollution cut into a financial asset," says Joseph Goffman, an attorney at Environmental Defense, "people go out and make lots of pollution cuts."',
#  'We are pretty close to finalizing a plan to open our system to everyone in terms of accepting limit orders and posting best bid/offer regardless of whose it is.',
#  'Give me a call if you want to discuss.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  "i think it's close to here.",
#  "i think it's close to here.",
#  'Think just as customers got totally fucked last year selling into the rally, they are going to buy all the way down.',
#  'i think the best play right now is to start buying longer  term put spreads.',
#  'i think the answer is no-not unless the economy was jump starter quickly-2nd q is gone,so maybe th 4q.',
#  'i think the answer is no-not unless the economy was jump starter quickly-2nd q is gone,so maybe th 4q.',
#  'We then provide you with access to, and help you select, third-party institutional money managers to make the day-to-day investment decisions.',
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  'Do you want to put some pressure on them, or would you rather wait to see if they can fix it to work on IE 5.0?',
#  'i think we would rally if march were the only thing traded.',
#  'slafontaine@globalp.com on 12/12/2000 03:22:07 PM To: slafontaine@globalp.com cc: jarnold@enron.com Subject: re:f/g if you havent read this yet youl think im brilliant-too bad i didnt short jan/feb or apr/may!',
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  'Or call us at #954/340/1628 leave yo= ur=20 email=20 address for removal from the database and future mailings.',
#  'Do you think that you could talk with one of your contacts and get her a pair of Rockets tickets.',
#  'Would they be interested in the same service we give Tudor, i.e do they want a salesperson to bring them ideas from our various trading groups??',
#  'Let me know and then I will send an email out to the desk to make arrangements to attend the meeting that day.',
#  'His comment was that Bradford is going through defcom 3 over California right now and to give him a week when things start to get sorted out there.',
#  'Nothing has changed that nor do I think we need to act weird around each other going forward.',
#  'What, do you think that should help you score women.',
#  'We are currently working with EOL to attain a solution, and need your help to build an inventory of all potential problems.',
#  'John: I would like for you to come talk to a couple more people on the gas floor about a possible position down the road.',
#  '(Jan 12-14)  If you are going to spend a fortune on your painting, you should at least see it one more time before you buy it.',
#  "asshole John J Lavorato@ENRON 12/23/2000 10:51 AM To: John Arnold/HOU/ECT@ECT cc: Subject: john I cant' seem to make my gambling problem go away.",
#  'He asked the head EOL marketer to give him a call about setting him up on the system.',
#  'that said everyone at pira including pira all bull bull the winter-will be good i think for a win/sum01/win02 inverse play even tho its not cheap.',
#  "Consequently, I think it's probably a good idea for me to make sure I'm focused on the right accounts for you.",
#  'What, do you think that should help you score women.',
#  'We are currently working with EOL to attain a solution, and need your help to build an inventory of all potential problems.',
#  'John: I would like for you to come talk to a couple more people on the gas floor about a possible position down the road.',
#  'I will call you tomorrow to touch base.',
#  '(Jan 12-14)  If you are going to spend a fortune on your painting, you should at least see it one more time before you buy it.',
#  "asshole John J Lavorato@ENRON 12/23/2000 10:51 AM To: John Arnold/HOU/ECT@ECT cc: Subject: john I cant' seem to make my gambling problem go away.",
#  'He asked the head EOL marketer to give him a call about setting him up on the system.',
#  'You guys make the call as to whether the additional 200 k is worth the weight it will lend to the EBS/BMC deal.',
#  'If we go TidalSoft I need to push this through or be advised to let it go till the New Year.',
#  'Regarding the relationship between Compaq and Enron, I need to make some things are very clear in our go forward strategy.',
#  'I need your help with all Enron organizations to make sure that they use Dave as the focal point.',
#  'Then Peter G. literally read from my notes the "message" you gave him about the need for HP to support the process on both the buy and sell sides.',
#  'The call went well, message was delivered and Darrin will follow up with HP so they can come in to Enron and present the wireless intiative.',
#  'We would appreciate if you could give us the names of additional brokers we could talk to that are active in your products.',
#  "I'll call later to see what you think of the idea.",
#  'Johnny recommended I have you speak to them- can you give me a few minutes during the day to talk to them about the west in general.',
#  'slafontaine@globalp.com on 12/12/2000 03:22:07 PM To: slafontaine@globalp.com cc: jarnold@enron.com Subject: re:f/g if you havent read this yet youl think im brilliant-too bad i didnt short jan/feb or apr/may!',
#  'One yelled at Rappaport... "Why don\'t you take your million dollar bonus and go buy Enron stock"',
#  'I can sit down with you when I am down there to discuss and give you an update of who we are planning to trade with.',
#  'Jennifer Stewart Medcalf will give you a call with further details.',
#  "723, depart 8:02pm, arrive 09:08pm I'll talk with you Tuesday evening before I leave.?",
#  'I would love to sit down and visit with you for about 30 minutes in the early part of December.',
#  'I was  under the impression after my visit to Houston that we were about to enter into  a trial agreement for my advisory work.?',
#  'It may help if you give specific positions that interest you most as Enron is such a big place, it will help focus the resume to the right people.',
#  'It may help if you give specific positions that interest you most as Enron is such a big place, it will help focus the resume to the right people.',
#  'I think I need to move back...',
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  'Do you want to put some pressure on them, or would you rather wait to see if they can fix it to work on IE 5.0?',
#  "Trade them up Johnny, Margarita John Arnold@ECT 10/25/2000 07:34 AM  To: Margaret Allen/Corp/Enron@ENRON cc: Subject: Re: Deathly afraid doesn't even come close to describing it.",
#  'I will give you a call to discuss the results and >    our >    next steps.',
#  'that said everyone at pira including pira all bull bull the winter-will be good i think for a win/sum01/win02 inverse play even tho its not cheap.',
#  "slafontaine@globalp.com on 10/13/2000 09:42:43 AM To: jarnold@enron.com cc: Subject: mkts cmon give me some credit-you think ive been doing this this long w/out know who's doing what!",
#  'Give me a call or email me and let me know when you have a second or two.',
#  'I would argue that technology will make open outcry exchanges extinct.',
#  'If you have any difficulty opening or using the file, please write to me or give me a call.',
#  'If you have any difficulty opening or using the file, please write to me or give me a call.',
#  'However, this market needs another 1-2 weeks of what I would  call horizontal price action to set the stage for a big move to the  upside.',
#  'However, this market needs another 1-2 weeks of what I would  call horizontal price action to set the stage for a big move to the  upside.',
#  'Russell: I think I should give you a little background on small ventures.',
#  'Please give me a call when you have an opportunity.',
#  'I think about that every time I go there.... Take care and make money!',
#  'Jeff had also asked that you spend some time with him so that a decision could be made as to whether or not to make him an offer.',
#  'I think about that every time I go there.... Take care and make money!',
#  'Dave: A couple things about the limit orders: 1:  When a customer opens up the limit order box, I think the time open should default to 12 hours.',
#  'I think we would bring him as an associate with the hope that he would move up to manager in 6 months.',
#  'I think about that every time I go there.... Take care and make money!',
#  "Hope things are going  well... can't wait for football... lemme know when  you boys come back out here... Andy",
#  'I will do my best to help any of you make things happen by January 4th.',
#  "Call me when ready and I'll come collect or send to EB2801e.",
#  'In this case I think 100 is necessary because once a strike has open interest, we must continue to support it.',
#  'Whereas if someone buys the 3085 straddle and the market moves to 3200, they have to call ENE to close the trade.',
#  'Anyway, I was going to go tonight to prepare for my trip to Mexico BUT, when I called, they said I should wait until I get back.',
#  'During this period, you can use Outlook Web Access (OWA) via your web browser (Internet Explorer 5.0) to read and send mail.',
#  'John, Do you think we need to see about sending an IT Tech for you and Maggi on Friday to make sure everything is working okay?',
#  'i think the velocity of the down move will be much less severe from here.',
#  'think a lot of spec shorts are looking to take profits as we get close to the psychological 400 target.',
#  "I'll call later to see what you think of the idea.",
#  'Thanks for your help and please call me with any questions.',
#  "- With only two days to call your own, you've got to make them count.",
#  ":-) If you would like further assistance, we're happy to help - please send E-mail to support@evite.citysearch.com * Updated 01/09/01.",
#  "I think it's time to go have a little fun with the group driving Enron's success.",
#  'call me if you want to talk further.... thanks for the article.',
#  'call me if you want to talk further.... thanks for the article.',
#  'Hi All, I think we should play hard ball with these guys.',
#  'residential conservation i think is underestimated and has a severe lag effect that will not come back as prices fall.',
#  'I might give him a call - he may be expensive - they had their own boat.',
#  'I might give him a call - he may be expensive - they had their own boat.',
#  'Patrick and I feel this call swayed a bit off track, and would like to make some corrections to the messages that were delivered today.',
#  'give me a call soon to  dicuss how to most effectively use the line.',
#  'if you want to discuss further give me a call 4-6 pm houston time.',
#  'If there are any other EBS deals/contracts on the table involving BMC, I would like to do whatever I could to help them close on this.',
#  "Think about what you want to do, and I'll call you tonight to discuss: Do you want to spend the long weekend with me or do your own thing?",
#  'If you want to spend it with me, would you rather go to the beach or to NYC?',
#  "when we get into injections, i think we'll see a big push down.",
#  'i think we close the y on y gap still significantly but im starting to question how when,how much and how long prices come off in apr-jun?',
#  "when we get into injections, i think we'll see a big push down.",
#  "however i think when the picture becomes clearer (i.e.-when we start beating last year's injections by 20 bcf a week), trade will get short.",
#  'i think we close the y on y gap still significantly but im starting to question how when,how much and how long prices come off in apr-jun?',
#  '"Whenever you turn a pollution cut into a financial asset," says Joseph Goffman, an attorney at Environmental Defense, "people go out and make lots of pollution cuts."',
#  'We are pretty close to finalizing a plan to open our system to everyone in terms of accepting limit orders and posting best bid/offer regardless of whose it is.',
#  'Give me a call if you want to discuss.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  "i think it's close to here.",
#  "i think it's close to here.",
#  'Think just as customers got totally fucked last year selling into the rally, they are going to buy all the way down.',
#  'i think the best play right now is to start buying longer  term put spreads.',
#  'i think the answer is no-not unless the economy was jump starter quickly-2nd q is gone,so maybe th 4q.',
#  'i think the answer is no-not unless the economy was jump starter quickly-2nd q is gone,so maybe th 4q.',
#  'We then provide you with access to, and help you select, third-party institutional money managers to make the day-to-day investment decisions.',
#  'I will call you tomorrow to touch base.',
#  'i think we would rally if march were the only thing traded.',
#  'This is a good account; I need your help to make sure we provide them the proper contact.',
#  'Can you give Sara-Joy Hunter a call at Enron?',
#  '> > Will not ask for anything else until I close this account :)))))!!!!',
#  'Or call us at #954/340/1628 leave yo= ur=20 email=20 address for removal from the database and future mailings.',
#  'Do you think that you could talk with one of your contacts and get her a pair of Rockets tickets.',
#  'Would they be interested in the same service we give Tudor, i.e do they want a salesperson to bring them ideas from our various trading groups??',
#  'Let me know and then I will send an email out to the desk to make arrangements to attend the meeting that day.',
#  'His comment was that Bradford is going through defcom 3 over California right now and to give him a week when things start to get sorted out there.',
#  'Nothing has changed that nor do I think we need to act weird around each other going forward.',
#  'I will call you tomorrow to touch base.',
#  'I will call you tomorrow to touch base.',
#  'You guys make the call as to whether the additional 200 k is worth the weight it will lend to the EBS/BMC deal.',
#  'If we go TidalSoft I need to push this through or be advised to let it go till the New Year.',
#  'I will give you a call to discuss the results and >    our >    next steps.',
#  'If there are any other EBS deals/contracts on the table involving BMC, I would like to do whatever I could to help them close on this.',
#  'Jennifer Stewart Medcalf will give you a call with further details.',
#  'Regarding the relationship between Compaq and Enron, I need to make some things are very clear in our go forward strategy.',
#  'I need your help with all Enron organizations to make sure that they use Dave as the focal point.',
#  'I will do my best to help any of you make things happen by January 4th.',
#  'But they`re coming down now and will be more moderate we think out over the next year but didn`t play any role in this.',
#  'They will play a real role because we could bring the gas supply asset storage and so on of our company to Portland General Electric`s gas-fired generation.',
#  'But there`s terrific overlap, a lot of savings for customers as we move forward to bring the companies together and certainly the accretion for our shareholders as well.',
#  "I don't think Brian can go - but can I extend the offer to him?",
#  "-----Original Message----- From: \tAllen, Margaret Sent:\tTuesday, October 09, 2001 10:50 AM To:\tArnold, John Subject:\tRE: He can't go - I didn't think he could.",
#  "He can't go - I didn't think he could.",
#  'You will be prompted to enter your basic information and make selections for your hotel room, travel and preferred activity.',
#  'The RSVP deadline has been extended to Monday, October 8, so if you pland to attend, please send a response to youngleaders@uwtgc.org or call 713/685-2306.',
#  'I actually think he might make a better orig guy.',
#  'After the current events calm down, we can talk via phone about my experience here and why I think there are some good opportunities here.',
#  'just doesnt fit the curve and i think 80% probabitly we end march with over 1.3 tcf in the ground.',
#  'i think the phys problem come a bit earlier.',
#  'She had heard I was in town and has been trying to get a hold of me to help her start her hedge fund.',
#  'He is trying to pressure the y/y spreads as a spec trade that I think was/is being done to front run the corp hedges.',
#  "If you want to buy this strip back in the next 6 months, I think it's going to be much easier/cheaper to roll it closer.",
#  'However, if  you still have not received your tickets the day before the event, please call (514)528-2828 and ask for a customer service supervisor.',
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com 1.',
#  "Just >    give >    me >    > a call when you're close and I'll meet you on the street right in >    front of >    > the building.",
#  'Make trades in your Schwab SDA brokerage account so that we can move your holdings in-kind.',
#  'Feel free to give us a call toll free at 877-LIBATION (877 542-2846).',
#  'The Oct. 29 conference will help the commission determine aspects of the price control that the parties involved agree are working and those that are not, she said.',
#  'stg operators dont have room to buy baseload gas and I think utilities will be planning to meet load using stg.',
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com 1.',
#  'stg operators dont have room to buy baseload gas and I think utilities will be planning to meet load using stg.',
#  '"To the extent that they can take more writedowns, I think it would make eminently good sense to do it."',
#  'I still think it\'s probably at least two years away, before we actually call it a trading commodity."',
#  'I will do my best to provide answers and talk about where we go from here.',
#  '"It\'s easy for the market to kick a company when its down, but these challenges do not last for a solid company, and we think Enron is one."',
#  'We want to go further and provide you with an even better place on the Internet to buy and sell wine.',
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com 1.',
#  '"It\'s easy for the market to kick a company when its down, but these challenges do not last for a solid company, and we think Enron is one."',
#  'Los Angeles is the first U.S. team to play in a Regional Championship, a Division I Championship and the U.S. Open Cup Final in the same calendar year.',
#  'But he refused to go into detail on the transaction that Enron made with partnerships run by Andrew S. Fastow, the chief financial officer.',
#  'Investors typically buy straddles if they expect a big move in the underlying stock, while sellers pocket premium and hope the stock remains in a tight trading range.',
#  'FRANCIS: Lets go to Keith in Alaska with a quick question for Don and Don let`s give us a zippy answer to.',
#  'Think that with this bidweek being, as we stand now, above resid and above the coal stack, fundamentals worsen considerably to the point where price must go down.',
#  'Please contact Janice Riedel at X-37507 or Cathy Phillips at X-36898 to sign up as a walker, make a donation, or ask any questions you may have.',
#  "Ok I'm beginning to think that I am going to have to ask you out on a date in order to get my necklace back.",
#  'Simply because I love the Spiderman theme song and I like to think I move across the field with the speed, agility and grace of a spider.',
#  'Continue: http://www.ussoccer.com/news/fullstory.sps?iNewsid=2470 10) "YOU DON\'T KNOW JACK (MARSHALL)" (U.S. Open Cup history) Think you know your U.S. Soccer trivia?',
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com The countdown to our Customer Appreciation Sale is on!!!',
#  "Don't Wait Any Longer, Start Making the Money You Deserve Today.",
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com 1.',
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com ************************** Huge Savings!!!!',
#  '93 points, drinkable, a great buy.... what else can you ask for, fist come first serve.',
#  '[= IMAGE] [IMAGE]  CD Box Sets Make Great Holiday Gifts  Give all the hits, pl= us extras like rare tracks, live performances, and photo booklets.',
#  'The company will pay new agents $1,500 a month for three months to give them time to make connections and sell a home.',
#  'MANAGING EDITOR: Well that`s right Kathleen but the interesting thing that make it perhaps not so done a deal is what we might call the materially adverse clause.',
#  "If I hear of any positions open I'll > give you a shout.",
#  'The market sold off so sharpl= y as to push yields, which move inversely to prices, almost back up to wher= e they stood before the terrorist attacks.',
#  'However, I have adivsed them I would keep in touch with them - should this change I will give you a call and give you an update.',
#  'Let me know if you have any questions with respect to the rotations outlined and we can make the appropriate changes as we move forward.',
#  "I can't wait to see you go down with the ship like all the other vermin.",
#  'PLEASE CALL 973-376-0005 ask for Order Dept.www.winelibrary.com=20 or e-mail us at swl@winelibrary.com=20 1.',
#  '[IMAGE]     Quicken  2002 Deluxe is packed wi= th powerful features to help give  you a more complete and accurate picture= of your finances.',
#  'These notes essentially are synthetic Enron debts, meaning they act like Enron bonds in many respects, but lack key components that make holders true creditors of Enron.',
#  "Those assets will enhance trading to bring costs down for the gas-fired generation and give us more options.''",
#  'just doesnt fit the curve > and i think 80% probabitly we end march with over 1.3 tcf in the ground.',
#  'Dave: A couple things about the limit orders: 1:  When a customer opens up the limit order box, I think the time open should default to 12 hours.',
#  'Jeff had also asked that you spend some time with him so that a decision could be made as to whether or not to make him an offer.',
#  'Russell: I think I should give you a little background on small ventures.',
#  'If you have any difficulty opening or using the file, please write to me or give me a call.',
#  'It may help if you give specific positions that interest you most as Enron is such a big place, it will help focus the resume to the right people.',
#  'I was  under the impression after my visit to Houston that we were about to enter into  a trial agreement for my advisory work.?',
#  "723, depart 8:02pm, arrive 09:08pm I'll talk with you Tuesday evening before I leave.?",
#  'One yelled at Rappaport... "Why don\'t you take your million dollar bonus and go buy Enron stock"',
#  'Johnny recommended I have you speak to them- can you give me a few minutes during the day to talk to them about the west in general.',
#  'He asked the head EOL marketer to give him a call about setting him up on the system.',
#  'John: I would like for you to come talk to a couple more people on the gas floor about a possible position down the road.',
#  'We are currently working with EOL to attain a solution, and need your help to build an inventory of all potential problems.',
#  'We would appreciate if you could give us the names of additional brokers we could talk to that are active in your products.',
#  'Nothing has changed that nor do I think we need to act weird around each other going forward.',
#  'His comment was that Bradford is going through defcom 3 over California right now and to give him a week when things start to get sorted out there.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  'Then, when prompted, enter the following information... Group ID#: 36853 Password: done We will send you a confirmation with further details once you have completed the registration process.',
#  '"Whenever you turn a pollution cut into a financial asset," says Joseph Goffman, an attorney at Environmental Defense, "people go out and make lots of pollution cuts."',
#  'call me if you want to talk further.... thanks for the article.',
#  "I think it's time to go have a little fun with the group driving Enron's success.",
#  "- With only two days to call your own, you've got to make them count.",
# ...
#  'i would give him a call Bryan Hull 04/03/2001 09:59 AM To:\tEric Bass/HOU/ECT@ECT cc: Subject: Did you ever ask Tom if was looking for an analyst?',
#  'Let me know "Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 09:39:48 AM To:   "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject:  RE: Give me a call That sounds viable.',
#  '"Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 08:49:24 AM To:   "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject:  RE: Give me a call Eric, Let me know if I have Anderson or not.',
#  'Let me know "Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 09:39:48 AM To: "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject: RE: Give me a call That sounds viable.',
#  '"Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 08:49:24 AM To:   "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject:  RE: Give me a call Eric, Let me know if I have Anderson or not.',
#  '"Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 08:49:24 AM To:   "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject:  RE: Give me a call Eric, Let me know if I have Anderson or not.',
#  '"Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 08:49:24 AM To:   "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject:  RE: Give me a call Eric, Let me know if I have Anderson or not.',
#  '"Bass, Jason" <Jason.Bass2@COMPAQ.com> on 09/21/2000 08:49:24 AM To: "\'Eric.Bass@enron.com\'" <Eric.Bass@enron.com> cc: Subject: RE: Give me a call Eric, Let me know if I have Anderson or not.',
#  "In case you're wondering why we play the Jay Ballers, the team we beat last week, three times during the season and the Raiders only once, don't ask me.",
#  'You will probably get there before us so just > leave a message at the desk or call us on the car phone.',
#  'You will probably get there before us so just leave a message at the desk or call us on the car phone.',
#  'We are willing to accept their help and give our help to others.',
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  'So,  I think Jason is going to go to the game now.',
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  'I would like to leave around 3:00 on Friday to go to Austin.',
#  'I would like to leave around 3:00 on Friday to go to Austin.',
#  'I think that i have a good enough team to withstand a bad start and make it to the playoffs anyway.',
#  'I think that i have a good enough team to withstand a bad start and make it to the playoffs anyway.',
#  'some people have come to me requesting a vote please go to the website and vote on the trade between the the Lie Downs and the Rounders',
#  '> > maybe i can come out this weekend to visit ( if you can fit me in).',
#  'maybe i can come out this weekend to visit ( if you can fit me in).',
#  'i think we should be able to make it out on saturday for lunch.',
#  'Mike, please give me a call at 3-0977 and we can set up a time that is good for you to observe.',
#  "When he sits with Risk, he'll probably go home and them return when you all start calcing.",
#  "that we should be glad God doesn't give us everything we ask for.",
#  'If they do not, it is up to you to make the first move and ask to schedule the meeting.',
#  'It is what you think you can make up with the additional picks.',
#  "If I can't play do you want me to ask Jody to play or just go with seven?",
#  'I leave Friday, July 14th, but before I go I would like to throw a going away bash.',
#  "If you need directions, leave me a message on my voice mail and I'll call you back...since I will out on vacation for most of next week.",
#  'Call 911, and tell them that they should arrive within 30 >seconds.',
#  'i think this is a call for help.',
#  "I don't agree with Darwin, but I didn't go  out and hire a lawyer when my high school teacher taught his theory of  evolution.",
#  "Ask around and let's all try and find a gym so we don't have to play outside.",
#  "Ask around and let's all try and find a gym so we don't have to play outside.",
#  'The Rockets have been considering a move since November, when voters in=20 Houston rejected a plan to build them a $160 million arena.',
#  'I would hate to have to come to work at 9:00 am and leave at 5:00 everyday.',
#  'I would hate to have to come to work at 9:00 am and leave at 5:00 everyday.',
#  "He can play both guard positions, he's one of the better defenders in the draft and would give the Bulls some versatility on the floor.",
#  'Let me know around 5- when you are ready to leave for the little happy hour- and we can walk over together.',
#  "I'll give you a call later.",
#  'We will get you as close as we can, and we will give you some idea of how close these Position Values will be.',
#  'You are going to have to make your own call on this one.',
#  'If you like the idea and you think they can execute, then go for it.',
#  'Let me know if you need me to give you more specific info .... thanks for your help .... :) Brandi - RESUME.doc',
#  'no, we are fine Luis Mena@ENRON_DEVELOPMENT 03/27/2000 01:15 PM To: Eric Bass/HOU/ECT@ECT cc: Subject: Re: Hey, should I bring a friend to make sure we have 8 or what???',
#  "Oh wait that's what I do at work to help me think about something other than losing lots of money - never mind.",
#  "I don't think you can make a case that you were smart for betting me without the points.",
#  "Oh wait that's what I do at work to help me think about something other than losing lots of money - never mind.",
#  'Why are you too cool to write me or call me?',
#  "i'll give you a call after trading",
#  'He gets 50 cents every time the site is hit, so take the time and visit the site to help an aspiring doctor.',
#  'I think you read too much into me.',
#  'I think you read too much into me.',
#  'If you want, we could sit down and go over it to see what needs to be done.',
#  'If you want, we could sit down and go over it to see what needs to be done.',
#  'I will bring you up to date now, but, before you read on, please sit down.',
#  'We are willing to accept their help and give our help to others.',
#  "In case you're wondering why we play the Jay Ballers, the team we beat last week, three times during the season and the Raiders only once, don't ask me.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  'So,  I think Jason is going to go to the game now.',
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  "I don't know if you want to sit in the student section b/c you really won't be sitting much - most of the students stand up the entire game.",
#  '=09 =09 =09 =09 =09 =09 =09[IMAGE] Casey Hampton =20 =09 =09Q: How high do you think Casey Hampton will go in the NFL draft?',
#  'And I think it will be difficult for the coaches not to start Simms= =20 next year.',
#  "We did a limited  run so if you're up for one, follow the link and go for it.?",
#  'I would like to leave around 3:00 on Friday to go to Austin.',
#  'I would like to leave around 3:00 on Friday to go to Austin.',
#  'I think that i have a good enough team to withstand a bad start and make it to the playoffs anyway.',
#  'I think that i have a good enough team to withstand a bad start and make it to the playoffs anyway.',
#  'some people have come to me requesting a vote please go to the website and vote on the trade between the the Lie Downs and the Rounders',
#  '> > maybe i can come out this weekend to visit ( if you can fit me in).',
#  'Would you please visit our new transition website at http://www.bushcheneytransition.com and make a contribution on our secure server?',
#  'maybe i can come out this weekend to visit ( if you can fit me in).',
#  'i think we should be able to make it out on saturday for lunch.',
#  'Mike, please give me a call at 3-0977 and we can set up a time that is good for you to observe.',
#  "When he sits with Risk, he'll probably go home and them return when you all start calcing.",
#  "that we should be glad God doesn't give us everything we ask for.",
#  'If they do not, it is up to you to make the first move and ask to schedule the meeting.',
#  'It is what you think you can make up with the additional picks.',
#  "If I can't play do you want me to ask Jody to play or just go with seven?",
#  'I leave Friday, July 14th, but before I go I would like to throw a going away bash.',
#  "If you need directions, leave me a message on my voice mail and I'll call you back...since I will out on vacation for most of next week.",
#  'Call 911, and tell them that they should arrive within 30 >seconds.',
#  'i think this is a call for help.',
#  "I don't agree with Darwin, but I didn't go  out and hire a lawyer when my high school teacher taught his theory of  evolution.",
#  "Ask around and let's all try and find a gym so we don't have to play outside.",
#  "Ask around and let's all try and find a gym so we don't have to play outside.",
#  'The Rockets have been considering a move since November, when voters in=20 Houston rejected a plan to build them a $160 million arena.',
#  'I would hate to have to come to work at 9:00 am and leave at 5:00 everyday.',
#  'I would hate to have to come to work at 9:00 am and leave at 5:00 everyday.',
#  "He can play both guard positions, he's one of the better defenders in the draft and would give the Bulls some versatility on the floor.",
#  'Let me know around 5- when you are ready to leave for the little happy hour- and we can walk over together.',
#  "I'll give you a call later.",
#  'We will get you as close as we can, and we will give you some idea of how close these Position Values will be.',
#  'You are going to have to make your own call on this one.',
#  'If you like the idea and you think they can execute, then go for it.',
#  'Let me know if you need me to give you more specific info .... thanks for your help .... :) Brandi - RESUME.doc',
#  'no, we are fine Luis Mena@ENRON_DEVELOPMENT 03/27/2000 01:15 PM To: Eric Bass/HOU/ECT@ECT cc: Subject: Re: Hey, should I bring a friend to make sure we have 8 or what???',
#  "Oh wait that's what I do at work to help me think about something other than losing lots of money - never mind.",
#  "I don't think you can make a case that you were smart for betting me without the points.",
#  "Oh wait that's what I do at work to help me think about something other than losing lots of money - never mind.",
#  'Why are you too cool to write me or call me?',
#  "i'll give you a call after trading",
#  'If you still need to get in touch with us about your order, send an e-mail message to orders@amazon.com.',
#  'He gets 50 cents every time the site is hit, so take the time and visit the site to help an aspiring doctor.',
#  'I think you read too much into me.',
#  'I think you read too much into me.',
#  'If you want, we could sit down and go over it to see what needs to be done.',
#  'If you want, we could sit down and go over it to see what needs to be done.',
#  'If you talk about race, it does not make you a racist.',
#  'If you think critically about a denomination, it does not make you anti-religion.',
#  'Call us at 800-525-7654 to receive a ski vacation package quote to include your lodging, airfare, ground transportation and lift tickets.',
#  'If you talk about race, it does not make you a racist.',
#  'If you think critically about a denomination, it does not make you anti-religion.',
#  'If you talk about race, it does not make you a racist.',
#  'If you think critically about a denomination, it does not make you anti-religion.',
#  "And when you're doing your last minute shopping this  holiday, visit us online at http://www.giftbaskets.com or call us at 1-800-461-6836.",
#  'My address is 2512 Milam St. #5216 Houston, TX 77006 If you won $ please give me your address and I will send you a check!',
#  'Give me a call if you have any questions.',
#  "Yes, he'll make some  young QB= =20 mistakes and I'd be surprised if he didn't throw as many interceptions  as = he=20 does TDs.?",
#  "I'll be up late tonight watching the national championship, so give me a call when you get in.",
#  "If not, I'll give you a call tomorrow night.",
#  "I'll give you a call tomorrow to let you know all of the details.",
#  'i would give him a call Bryan Hull 04/03/2001 09:59 AM To: Eric Bass/HOU/ECT@ECT cc: Subject: Did you ever ask Tom if was looking for an analyst?',
#  'Does anybody want to go see him on Friday March 30?',
#  "I can't make it for dinner - but we might be able to come for drinks afterwards.",
#  'I think that would help out in recruiting a lot.',
#  "Write this code down, because you'll need to enter it in the appropriate field when you check out.",
#  "Write this code down, because you'll need to enter it in the appropriate field when you check out.",
#  "Write this code down, because you'll need to enter it in the appropriate field when you check out.",
#  "I can't make it this week, but I will bring in your jersey .",
#  "> We > > > > could wait until the weekend to see what's open and make appts.",
#  "We > > > could wait until the weekend to see what's open and make appts.",
#  "We > > could wait until the weekend to see what's open and make appts.",
#  "We > could wait until the weekend to see what's open and make appts.",
#  "We could wait until the weekend to see what's open and make appts.",
#  'Can you call the realtor and ask about Prop.',
#  "i don't think we are going to be able to make it out that way tonight.",
#  'I think Michael and his girlfriend are going to come as well and we were thinking about going out somewhere afterwards.',
#  'You can make the changes in the document and send the changed  document back.?',
#  'You  can make the changes in the document and send the changed document back.',
#  'You  can make the changes in the document and send the changed document back.?',
#  'Shanna is going to visit Toni tomorrow, apparently she has taken a turn for the worse.',
#  'Give me a call on my cell phone tonight or tomorrow - 713-628-3104.',
#  'Shanna is going to visit Toni tomorrow, apparently she has taken a turn for the worse.',
#  'he can go there with all the talent in the world and get run by the pac-10.',
#  'he can go there with all the talent in the world and get run by the pac-10.',
#  'So I will give you a call from there.',
#  'Do you think we should tack on $5 mil and try to run that through?',
#  'Do you think we should tack on $5 mil and try to run that through?',
#  "Why don't you call and get your lab work done that day and we'll go for lunch?",
#  "I can't think of anybody I'd rather spend the evening with than my wonderful men and the boys' signficant others.",
#  "Why don't you call and get your lab work done that day and we'll go for lunch?",
#  "I can't think of anybody I'd rather spend the evening with than my wonderful men and the boys' signficant others.",
#  'Call before you leave for CA.?',
#  'I rate Wilkins chance to start  at close to 90% this week.',
#  '56% Bush 25% Gore Do you think Gore should concede the election or do you agree with his decision to contest the Florida election results?',
#  ...]
